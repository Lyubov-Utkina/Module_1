# %% [markdown]
# <img src="https://whatcar.vn/media/2018/09/car-lot-940x470.jpg"/>

# %% [markdown]
# Проект 6 "Выбираем авто выгодно" выполнен в составе команды BALU с Алексеем Блинниковым. Алексей в большей степени выполнял парсинг, первичный анализ данных, стекинг. Я больше занималась feature engineering и подбором модели. Хотя у нас были примерно размечены области работы, мы обсуждали и принимали участие во всех этапах работы. В результате я получила бесценный опыт чтения чужого кода, обмена опытом, знаниями и находками

# %%
# Загрузка ОС и файлов для работы на Kaggle

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/sf-dst-car-price-prediction/sample_submission.csv
# /kaggle/input/sf-dst-car-price-prediction/test.csv
# /kaggle/input/car-price-spring-2021/extended_train.csv
# /kaggle/input/parsing-all-moscow-auto-ru-09-09-2020/all_auto_ru_09_09_2020.csv

# %%
# Загрузка библиотек

from IPython.display import display
from ipywidgets import IntProgress
from catboost import CatBoostRegressor
import numpy as np
import pandas as pd
import json
import ast
import re
from itertools import combinations
from statsmodels.stats import weightstats
from scipy import stats
from gensim.models import Word2Vec
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import seaborn as sns
import pandas_profiling
import warnings

import sys
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, RobustScaler
from sklearn.model_selection import train_test_split, StratifiedKFold, KFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, ExtraTreesRegressor
from nltk.corpus import stopwords
from sklearn.metrics import mean_absolute_error, mean_squared_error, silhouette_score
from tqdm.notebook import tqdm
from lightgbm import LGBMRegressor
from sklearn.ensemble import StackingRegressor

tqdm.pandas()

warnings.filterwarnings("ignore")

import lazypredict
from lazypredict.Supervised import LazyRegressor
from sklearn.utils import shuffle
# Out:
# /opt/conda/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel

# %%
# Фиксация версий пакетов для воспроизводимости экспериментов
# !pip freeze > requirements.txt

# %%
# Фиксация random seed для воспроизводимости экспериментов
RS = 42

# %%
# Функция возвращает целевую метрику
def MAPE(y_true, y_pred):
    return np.mean(np.abs((y_pred-y_true)/y_true))

# %%
# Загрузка данных в переменные
# DIR_TEST   = '../input/sf-dst-car-price-prediction/'
# test = pd.read_csv(DIR_TEST+'test.csv')
# sample_submission = pd.read_csv(DIR_TEST+'sample_submission.csv')

# Загрузка данных в переменные
test = pd.read_csv('test.csv')
sample_submission = pd.read_csv('sample_submission.csv')

# %% [markdown]
# # Первичный взгляд на данные

# %%
sample_submission.sample(3)
# Out:
#           sell_id  price
# 28807  1098725352      0
# 2260   1100615602      0
# 28098  1101317622      0

# %%
pd.options.display.max_columns = test.shape[1]
test.head(3)
# Out:
#   bodyType  brand                                            car_url   color  \
# 0  лифтбек  SKODA  https://auto.ru/cars/used/sale/skoda/octavia/1...   синий
# 1  лифтбек  SKODA  https://auto.ru/cars/used/sale/skoda/octavia/1...  чёрный
# 2  лифтбек  SKODA  https://auto.ru/cars/used/sale/skoda/superb/11...   серый
#
#                                   complectation_dict  \
# 0                                                NaN
# 1                                                NaN
# 2  {"id":"20026336","name":"Ambition","available_...
#
#                                          description engineDisplacement  \
# 0  Все автомобили, представленные в продаже, прох...            1.2 LTR
# 1  ЛОТ: 01217195\nАвтопрага Север\nДанный автомоб...            1.6 LTR
# 2  Все автомобили, представленные в продаже, прох...            1.8 LTR
#
#   enginePower                                     equipment_dict fuelType  \
# 0     105 N12  {"engine-proof":true,"tinted-glass":true,"airb...   бензин
# 1     110 N12  {"cruise-control":true,"asr":true,"esp":true,"...   бензин
# 2     152 N12  {"cruise-control":true,"tinted-glass":true,"es...   бензин
#
#                                                image  mileage  modelDate  \
# 0  https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...    74000       2013
# 1  https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...    60563       2017
# 2  https://avatars.mds.yandex.net/get-autoru-vos/...    88000       2013
#
#                                           model_info model_name  \
# 0  {"code":"OCTAVIA","name":"Octavia","ru_name":"...    OCTAVIA
# 1  {"code":"OCTAVIA","name":"Octavia","ru_name":"...    OCTAVIA
# 2  {"code":"SUPERB","name":"Superb","ru_name":"Су...     SUPERB
#
#                      name  numberOfDoors  parsing_unixtime priceCurrency  \
# 0      1.2 AMT (105 л.с.)              5        1603226273           RUB
# 1       1.6 MT (110 л.с.)              5        1603226277           RUB
# 2  DSG 1.8 AMT (152 л.с.)              5        1603226280           RUB
#
#    productionDate     sell_id  \
# 0            2014  1100575026
# 1            2017  1100549428
# 2            2014  1100658222
#
#                                            super_gen     vehicleConfiguration  \
# 0  {"id":"10373605","displacement":1197,"engine_t...       LIFTBACK ROBOT 1.2
# 1  {"id":"20913311","displacement":1598,"engine_t...  LIFTBACK MECHANICAL 1.6
# 2  {"id":"20026323","nameplate":"DSG","displaceme...       LIFTBACK ROBOT 1.8
#
#   vehicleTransmission    vendor    Владельцы Владение       ПТС    Привод  \
# 0    роботизированная  EUROPEAN  3 или более      NaN  Оригинал  передний
# 1        механическая  EUROPEAN   1 владелец      NaN  Оригинал  передний
# 2    роботизированная  EUROPEAN   1 владелец      NaN  Оригинал  передний
#
#     Руль           Состояние     Таможня
# 0  Левый  Не требует ремонта  Растаможен
# 1  Левый  Не требует ремонта  Растаможен
# 2  Левый  Не требует ремонта  Растаможен

# %%
# Обзор тестового датасета с помощью pandas_profiling
# test_profile = ProfileReport(test, title='Test Report', html={'style':{'full_width':True}})
# test_profile.to_widgets()
# Мы спрятали код в комментарии, потому что он некорректно работает в ноутбуке на kaggle

# %%
test.shape
# Out:
# (34686, 32)

# %%
# Функция возвращает визуализацию и относительную долю пропусков в данных
def na_values(df):
    fig, ax = plt.subplots(figsize=(12, 8))
    sns.heatmap(df.isnull(),
                yticklabels=False, 
                cbar=False,
                cmap='viridis')
    plt.show()
    
    for column in df.columns:
        value = df[column].isna().sum()
        if value > 0:
            print(column.upper())
            print('%% пропущенных данных в столбце: \t{}'.format(np.round(value/len(df[column])*100), 2))
            print('(%% от общего кол-ва данных: \t{})'.format(np.round(value/np.product(df.shape)*100), 2))
            print()

# %%
na_values(test)
# Out:
# COMPLECTATION_DICT
# %% пропущенных данных в столбце: 	81.0
# (%% от общего кол-ва данных: 	3.0)
#
# EQUIPMENT_DICT
# %% пропущенных данных в столбце: 	29.0
# (%% от общего кол-ва данных: 	1.0)
#
# ВЛАДЕНИЕ
# %% пропущенных данных в столбце: 	65.0
# (%% от общего кол-ва данных: 	2.0)
#
# ПТС
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)

# %% [markdown]
# # Предобработка

# %% [markdown]
# ## Подготовка для сбора обучающего датасета

# %%
# Уникальные пары brand - model_name
for_parsing = test[['brand','model_name']].drop_duplicates()
for_parsing.sample(3)
# Out:
#             brand      model_name
# 20192      TOYOTA  COROLLA_RUMION
# 27835  MITSUBISHI             RVR
# 11875      NISSAN            CUBE

# %%
# Проверка уникальности
for_parsing.model_name.value_counts().max()
# Out:
# 1

# %%
# Выгрузка
for_parsing.to_csv('band_model.csv', index=False)

# %%
len(test.columns)
# Out:
# 32

# %% [markdown]
# ## Загрузка обучающей выборки

# %% [markdown]
# ### Свежие данные

# %%
# Загрузка данных в переменные
# DIR_TRAIN   = '../input/car-price-spring-2021/'
# train = pd.read_csv(DIR_TRAIN+'extended_train.csv', index_col=0) # датасет для обучения модели

train = pd.read_csv('extended_train.csv', index_col=0)  # датасет для обучения модели

# %%
# Обзор тренировочного датасета с помощью pandas_profiling
# train_profile = ProfileReport(train, title='Train Report', html={'style':{'full_width':True}})
# train_profile.to_widgets()
# Мы спрятали код в комментарии, потому что он некорректно работает в ноутбуке на kaggle

# %%
pd.options.display.max_columns = train.shape[1]
train.head(3)
# Out:
#   bodyType  brand                                            car_url  \
# 0  лифтбек  SKODA  https://auto.ru/cars/used/sale/skoda/octavia/1...
# 1  лифтбек  SKODA  https://auto.ru/cars/used/sale/skoda/octavia/1...
# 2  лифтбек  SKODA  https://auto.ru/cars/used/sale/skoda/octavia/1...
#
#          color                                 complectation_dict  \
# 0  серебристый  {'id': '21151162', 'name': 'Style', 'available...
# 1        белый                                        {'id': '0'}
# 2        серый  {'id': '20803542', 'name': 'Ambition', 'availa...
#
#                                          description engineDisplacement  \
# 0  единственный собственник , куплена в июле 2016...            1.4 LTR
# 1  Продаёт - Собственник.\nВыпуск - декабрь 2018г...            1.6 LTR
# 2  Автомобиль в идеальном состоянии. Приобретен в...            1.8 LTR
#
#   enginePower                                     equipment_dict fuelType  \
# 0     150 N12  {'cruise-control': True, 'esp': True, 'adaptiv...   бензин
# 1     110 N12  {'leather-gear-stick': True, 'esp': True, 'ptf...   бензин
# 2     180 N12  {'asr': True, 'tinted-glass': True, 'esp': Tru...   бензин
#
#                                                image   mileage  modelDate  \
# 0  https://avatars.mds.yandex.net/get-autoru-vos/...   70000.0     2013.0
# 1  https://autoru.naydex.net/jsB9Y6O22/7f4364z4/Y...  120000.0     2017.0
# 2  https://autoru.naydex.net/jsB9Y6O22/7f4364z4/Y...   86000.0     2013.0
#
#                                           model_info model_name  \
# 0  {'code': 'OCTAVIA', 'name': 'Octavia', 'ru_nam...    OCTAVIA
# 1  {'code': 'OCTAVIA', 'name': 'Octavia', 'ru_nam...    OCTAVIA
# 2  {'code': 'OCTAVIA', 'name': 'Octavia', 'ru_nam...    OCTAVIA
#
#                  name  numberOfDoors  parsing_unixtime priceCurrency  \
# 0  1.4 AMT (150 л.с.)            5.0        1619648597           RUB
# 1   1.6 AT (110 л.с.)            5.0        1619648599           RUB
# 2   1.8 MT (180 л.с.)            5.0        1619648602           RUB
#
#    productionDate       sell_id  \
# 0          2016.0  1.102728e+09
# 1          2018.0  1.103302e+09
# 2          2013.0  1.103229e+09
#
#                                            super_gen     vehicleConfiguration  \
# 0  {'id': '9338208', 'name': 'III (A7)', 'ru_name...       LIFTBACK ROBOT 1.4
# 1  {'id': '20898195', 'name': 'III (A7) Рестайлин...   LIFTBACK AUTOMATIC 1.6
# 2  {'id': '9338208', 'name': 'III (A7)', 'ru_name...  LIFTBACK MECHANICAL 1.8
#
#   vehicleTransmission    vendor    Владельцы             Владение       ПТС  \
# 0    роботизированная  EUROPEAN   1 владелец  4 года и 10 месяцев  Оригинал
# 1      автоматическая  EUROPEAN  2 владельца                  NaN  Оригинал
# 2        механическая  EUROPEAN  2 владельца            9 месяцев  Оригинал
#
#      Привод   Руль           Состояние     Таможня  \
# 0  передний  Левый  Не требует ремонта  Растаможен
# 1  передний  Левый  Не требует ремонта  Растаможен
# 2  передний  Левый  Не требует ремонта  Растаможен
#
#                                           price_info
# 0  {'price': 1190000, 'currency': 'RUR', 'EUR': 1...
# 1  {'price': 980000, 'currency': 'RUR', 'EUR': 10...
# 2  {'price': 1020000, 'currency': 'RUR', 'EUR': 1...

# %%
na_values(train)
# Out:
# BODYTYPE
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# BRAND
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# COLOR
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# COMPLECTATION_DICT
# %% пропущенных данных в столбце: 	3.0
# (%% от общего кол-ва данных: 	0.0)
#
# DESCRIPTION
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# ENGINEDISPLACEMENT
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# ENGINEPOWER
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# EQUIPMENT_DICT
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# FUELTYPE
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# IMAGE
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# MILEAGE
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# MODELDATE
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# MODEL_INFO
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# MODEL_NAME
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# NAME
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# NUMBEROFDOORS
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# PRODUCTIONDATE
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# SELL_ID
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# SUPER_GEN
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# VEHICLECONFIGURATION
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# VEHICLETRANSMISSION
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# VENDOR
# %% пропущенных данных в столбце: 	4.0
# (%% от общего кол-ва данных: 	0.0)
#
# ВЛАДЕЛЬЦЫ
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# ВЛАДЕНИЕ
# %% пропущенных данных в столбце: 	72.0
# (%% от общего кол-ва данных: 	2.0)
#
# ПТС
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# ПРИВОД
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# РУЛЬ
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# СОСТОЯНИЕ
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# ТАМОЖНЯ
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# PRICE_INFO
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)

# %% [markdown]
# В тренировочной выборке больше признаков с пропущенными данными, по сравнению с тестовой выборкой. Необходимо избавиться от пропусков.

# %%
# Заполним пропуски признака vendor на основе модели автомобиля
eur_vendor = ['SKODA', 'MERCEDES', 'BMW', 'VOLKSWAGEN', 'VOLVO', 'AUDI']

def fill_vendor(row):
    if pd.isnull(row['vendor']):
        if row['brand'] in eur_vendor:
            return 'EUROPEAN'
        else:
            return 'JAPANESE'
    return row['vendor']
    
train['vendor'] = train.apply(fill_vendor, axis = 1)

# %%
# Для дальнейшей корректной работы в признак 'complectation_dict' вместо Nan поставим пустые словари
train['complectation_dict'].fillna(train['complectation_dict'].value_counts().index[0], inplace = True)

# %%
# Создание списка признаков, по которым в тестовой выборке нет пропусков
cols_to_clean=[]
for col in train.drop('price_info', axis=1).columns:
    if len(test[col].isna().unique())==1:
        cols_to_clean.append(col)

# %%
# Очистка от пропусков
train.dropna(inplace=True, subset=cols_to_clean)

# %%
train.shape
# Out:
# (84218, 33)

# %%
na_values(train)
# Out:
# ВЛАДЕНИЕ
# %% пропущенных данных в столбце: 	72.0
# (%% от общего кол-ва данных: 	2.0)
#
# ПТС
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)

# %%
train.sample(5)
# Out:
#             bodyType       brand  \
# 40677  хэтчбек 5 дв.      NISSAN
# 32968          седан         BMW
# 75768          седан  VOLKSWAGEN
# 80876          седан  MITSUBISHI
# 56478        минивэн    MERCEDES
#
#                                                  car_url       color  \
# 40677  https://auto.ru/cars/used/sale/nissan/note/110...       синий
# 32968  https://auto.ru/cars/used/sale/bmw/5er/1102520...  коричневый
# 75768  https://auto.ru/cars/used/sale/volkswagen/jett...      чёрный
# 80876  https://auto.ru/cars/used/sale/mitsubishi/lanc...       серый
# 56478  https://auto.ru/cars/used/sale/mercedes/vito/1...     зелёный
#
#                                       complectation_dict  \
# 40677  {'id': '4995160', 'name': 'Comfort', 'availabl...
# 32968  {'id': '6260984', 'name': '525d', 'available_o...
# 75768                                        {'id': '0'}
# 80876                                        {'id': '0'}
# 56478                                        {'id': '0'}
#
#                                              description engineDisplacement  \
# 40677  ПОЧЕМУ СТОИТ ПРИЕХАТЬ К НАМ ПРЯМО СЕЙЧАС?\n\nА...            1.4 LTR
# 32968  Автомобиль продаётся официальным дилером BMW -...            2.0 LTR
# 75768  .\nСпециальные условия покупки в мае:\n- При о...            1.4 LTR
# 80876  \n\nВ отличном состоянии для своих лет.\nПодкр...            1.5 LTR
# 56478  Автомобиль в очень хорошем состоянии для своих...            2.3 LTR
#
#       enginePower                                     equipment_dict fuelType  \
# 40677      88 N12  {'steel-wheels': True, 'airbag-driver': True, ...   бензин
# 32968     218 N12  {'cruise-control': True, 'asr': True, 'tinted-...   дизель
# 75768     122 N12  {'asr': True, 'condition': True, 'computer': T...   бензин
# 80876     109 N12  {'alloy-wheel-disks': True, 'esp': True, 'leat...   бензин
# 56478     143 N12  {'cruise-control': True, 'asr': True, 'tinted-...   бензин
#
#                                                    image   mileage  modelDate  \
# 40677  https://avatars.mds.yandex.net/get-autoru-vos/...  115600.0     2008.0
# 32968  https://autoru.naydex.net/GM1F7b109/be26c9wovz...  105968.0     2009.0
# 75768  https://avatars.mds.yandex.net/get-autoru-vos/...  219869.0     2010.0
# 80876  https://autoru.naydex.net/jwPR8c922/3385207cem...  131000.0     2007.0
# 56478  https://avatars.mds.yandex.net/get-autoru-vos/...  360000.0     1996.0
#
#                                               model_info model_name  \
# 40677  {'code': 'NOTE', 'name': 'Note', 'ru_name': 'Н...       NOTE
# 32968  {'code': '5ER', 'name': '5 серии', 'ru_name': ...        5ER
# 75768  {'code': 'JETTA', 'name': 'Jetta', 'ru_name': ...      JETTA
# 80876  {'code': 'LANCER', 'name': 'Lancer', 'ru_name'...     LANCER
# 56478  {'code': 'VITO', 'name': 'Vito', 'ru_name': 'в...       VITO
#
#                                      name  numberOfDoors  parsing_unixtime  \
# 40677                    1.4 MT (88 л.с.)            5.0        1620044715
# 32968  525d xDrive 2.0d AT (218 л.с.) 4WD            4.0        1620009526
# 75768                   1.4 MT (122 л.с.)            4.0        1620325830
# 80876                   1.5 AT (109 л.с.)            4.0        1620361077
# 56478               114 2.3 AT (143 л.с.)            4.0        1620202735
#
#       priceCurrency  productionDate       sell_id  \
# 40677           RUB          2012.0  1.102852e+09
# 32968           RUB          2012.0  1.102521e+09
# 75768           RUB          2011.0  1.103342e+09
# 80876           RUB          2010.0  1.102994e+09
# 56478           RUB          2001.0  1.103380e+09
#
#                                                super_gen  \
# 40677  {'id': '4994902', 'name': 'I Рестайлинг', 'ru_...
# 32968  {'id': '6088519', 'name': 'VI (F10/F11/F07)', ...
# 75768  {'id': '7355324', 'name': 'VI', 'ru_name': '6'...
# 80876  {'id': '20095920', 'name': 'X', 'ru_name': '10...
# 56478  {'id': '7911749', 'name': 'I (W638)', 'ru_name...
#
#                    vehicleConfiguration vehicleTransmission    vendor  \
# 40677  HATCHBACK_5_DOORS MECHANICAL 1.4        механическая  JAPANESE
# 32968               SEDAN AUTOMATIC 2.0      автоматическая  EUROPEAN
# 75768              SEDAN MECHANICAL 1.4        механическая  EUROPEAN
# 80876               SEDAN AUTOMATIC 1.5      автоматическая  JAPANESE
# 56478             MINIVAN AUTOMATIC 2.3      автоматическая  EUROPEAN
#
#          Владельцы Владение       ПТС    Привод   Руль           Состояние  \
# 40677  2 владельца      NaN  Оригинал  передний  Левый  Не требует ремонта
# 32968  2 владельца      NaN  Оригинал    полный  Левый  Не требует ремонта
# 75768   1 владелец      NaN  Оригинал  передний  Левый  Не требует ремонта
# 80876  2 владельца      NaN  Оригинал  передний  Левый  Не требует ремонта
# 56478  3 или более      NaN  Дубликат  передний  Левый  Не требует ремонта
#
#           Таможня                                         price_info
# 40677  Растаможен  {'price': 515000, 'currency': 'RUR', 'EUR': 56...
# 32968  Растаможен  {'price': 1379000, 'currency': 'RUR', 'EUR': 1...
# 75768  Растаможен  {'price': 590000, 'currency': 'RUR', 'EUR': 65...
# 80876  Растаможен  {'price': 539000, 'currency': 'RUR', 'EUR': 60...
# 56478  Растаможен  {'price': 480000, 'currency': 'RUR', 'EUR': 53...

# %% [markdown]
# Отсутствие пропусков по 'complectation_dict' и 'equipment_dict' в тренировочной выборке объясняется наличаем пустых словарей.

# %%
# Удаление дубликатов
train.drop_duplicates(subset=['sell_id'], inplace=True)

# %% [markdown]
# ## Преобразование строковых величин в словари

# %% [markdown]
# ### Тренировочная выборка

# %%
# Преобразование
for col in ['complectation_dict', 'equipment_dict',
            'model_info', 'super_gen', 'price_info']:
    train[col] = train[col].apply(lambda x: ast.literal_eval(x))

# %% [markdown]
# ### Тестовая выборка

# %%
# Функция возвращает словарь из строки
def str_to_dict(string):
    try:
        return json.loads(string)
    except:
        return None

# %%
# Применение функции str_to_dict
for col in ['complectation_dict', 'equipment_dict',
            'model_info', 'super_gen']:
    test[col] = test[col].apply(str_to_dict)

# %%
na_values(test)
# Out:
# COMPLECTATION_DICT
# %% пропущенных данных в столбце: 	81.0
# (%% от общего кол-ва данных: 	3.0)
#
# EQUIPMENT_DICT
# %% пропущенных данных в столбце: 	29.0
# (%% от общего кол-ва данных: 	1.0)
#
# ВЛАДЕНИЕ
# %% пропущенных данных в столбце: 	65.0
# (%% от общего кол-ва данных: 	2.0)
#
# ПТС
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)

# %% [markdown]
# Пропорции пропусков остались прежними, функция отработала корректно.

# %%
# Создаем признак цены в тесте
default_price = "{'price': 0, 'currency': 'RUR', 'EUR': 0, 'RUR': 0, 'USD': 0, 'with_nds': False}"
test['price_info'] = default_price
test['price_info'] = test.price_info.apply(lambda x: ast.literal_eval(x))

# %% [markdown]
# ## Совместная предобработка

# %%
# Создание метки тренировочной выборки
train['train'] = 1
test['train'] = 0

# Объединение выборок
data = train.append(test, sort=False).reset_index(drop=True)

# %%
data.sample(5)
# Out:
#                  bodyType       brand  \
# 52716   внедорожник 5 дв.    MERCEDES
# 21999               седан        AUDI
# 18562   внедорожник 5 дв.        AUDI
# 106871      хэтчбек 5 дв.  VOLKSWAGEN
# 502     внедорожник 5 дв.        AUDI
#
#                                                   car_url        color  \
# 52716   https://auto.ru/cars/used/sale/mercedes/gls_kl...       чёрный
# 21999   https://auto.ru/cars/used/sale/audi/a6/1100897...        серый
# 18562   https://auto.ru/cars/used/sale/audi/q5/1102553...      бежевый
# 106871  https://auto.ru/cars/used/sale/volkswagen/golf...  серебристый
# 502     https://auto.ru/cars/used/sale/audi/q3/1103333...        синий
#
#                                        complectation_dict  \
# 52716                                         {'id': '0'}
# 21999   {'id': '20725902', 'name': 'Business', 'availa...
# 18562                                         {'id': '0'}
# 106871                                               None
# 502                                           {'id': '0'}
#
#                                               description engineDisplacement  \
# 52716   Официальный дилер Mercedes-Benz \nООО «РОЛЬФ» ...            3.0 LTR
# 21999   Пробег 75.000 . Комплектация Business.  Обслуж...            2.0 LTR
# 18562   Выпуск сентябрь 2015, первая регистрация - в 2...            2.0 LTR
# 106871  Отличная машина, полностью обслужена.\nВторой ...            1.4 LTR
# 502     Автомобиль приобретался у официального дилера....            2.0 LTR
#
#        enginePower                                     equipment_dict  \
# 52716      249 N12  {'cruise-control': True, 'asr': True, 'start-s...
# 21999      249 N12  {'tinted-glass': True, 'esp': True, 'adaptive-...
# 18562      177 N12  {'alloy-wheel-disks': True, 'roof-rails': True...
# 106871     122 N12                                               None
# 502        180 N12  {'asr': True, 'tinted-glass': True, 'esp': Tru...
#
#        fuelType                                              image   mileage  \
# 52716    дизель  https://autoru.naydex.net/iZe1e7630/ef5c48LR/h...  106690.0
# 21999    бензин  https://avatars.mds.yandex.net/get-autoru-vos/...   75000.0
# 18562    дизель  https://autoru.naydex.net/rS94cSx48/668d04Abga...   14780.0
# 106871   бензин  https://autoru.naydex.net/o9DBXQ270/5ac010hAY0...  244000.0
# 502      бензин  https://avatars.mds.yandex.net/get-autoru-vos/...   53928.0
#
#         modelDate                                         model_info  \
# 52716      2015.0  {'code': 'GLS_KLASSE', 'name': 'GLS', 'ru_name...
# 21999      2014.0  {'code': 'A6', 'name': 'A6', 'ru_name': 'А6', ...
# 18562      2012.0  {'code': 'Q5', 'name': 'Q5', 'ru_name': 'Ку5',...
# 106871     2008.0  {'code': 'GOLF', 'name': 'Golf', 'ru_name': 'Г...
# 502        2014.0  {'code': 'Q3', 'name': 'Q3', 'ru_name': 'Ку3',...
#
#         model_name                          name  ...  priceCurrency  \
# 52716   GLS_KLASSE  350 d 3.0d AT (249 л.с.) 4WD  ...            RUB
# 21999           A6        2.0 AMT (249 л.с.) 4WD  ...            RUB
# 18562           Q5       2.0d AMT (177 л.с.) 4WD  ...            RUB
# 106871        GOLF             1.4 MT (122 л.с.)  ...            RUB
# 502             Q3        2.0 AMT (180 л.с.) 4WD  ...            RUB
#
#         productionDate       sell_id  \
# 52716           2018.0  1.103284e+09
# 21999           2016.0  1.100898e+09
# 18562           2015.0  1.102554e+09
# 106871          2009.0  1.097523e+09
# 502             2016.0  1.103334e+09
#
#                                                 super_gen  \
# 52716   {'id': '20712531', 'name': 'I (X166)', 'ru_nam...
# 21999   {'id': '20246005', 'name': 'IV (C7) Рестайлинг...
# 18562   {'id': '8351293', 'name': 'I (8R) Рестайлинг',...
# 106871  {'id': '4698288', 'displacement': 1390, 'engin...
# 502     {'id': '20293979', 'name': 'I (8U) Рестайлинг'...
#
#                     vehicleConfiguration vehicleTransmission    vendor  \
# 52716      ALLROAD_5_DOORS AUTOMATIC 3.0      автоматическая  EUROPEAN
# 21999                    SEDAN ROBOT 2.0    роботизированная  EUROPEAN
# 18562          ALLROAD_5_DOORS ROBOT 2.0    роботизированная  EUROPEAN
# 106871  HATCHBACK_5_DOORS MECHANICAL 1.4        механическая  EUROPEAN
# 502            ALLROAD_5_DOORS ROBOT 2.0    роботизированная  EUROPEAN
#
#           Владельцы           Владение       ПТС    Привод   Руль  \
# 52716   2 владельца                NaN  Оригинал    полный  Левый
# 21999   3 или более                NaN  Оригинал    полный  Левый
# 18562    1 владелец  4 года и 4 месяца  Оригинал    полный  Левый
# 106871  3 или более                NaN  Оригинал  передний  Левый
# 502      1 владелец                NaN  Оригинал    полный  Левый
#
#                  Состояние     Таможня  \
# 52716   Не требует ремонта  Растаможен
# 21999   Не требует ремонта  Растаможен
# 18562   Не требует ремонта  Растаможен
# 106871  Не требует ремонта  Растаможен
# 502     Не требует ремонта  Растаможен
#
#                                                price_info train
# 52716   {'price': 4542000, 'currency': 'RUR', 'EUR': 5...     1
# 21999   {'price': 2300000, 'currency': 'RUR', 'EUR': 2...     1
# 18562   {'price': 2599999, 'currency': 'RUR', 'EUR': 2...     1
# 106871  {'price': 0, 'currency': 'RUR', 'EUR': 0, 'RUR...     0
# 502     {'price': 1950000, 'currency': 'RUR', 'EUR': 2...     1
#
# [5 rows x 34 columns]

# %% [markdown]
# Функции для обработки:

# %%
# Фунция возвращает ID комплектации
def get_comp_id(dictionary):
    try:
        return dictionary['id']
    except:
        return 0
    
# Фунция возвращает название комплектации
def get_comp_name(dictionary):
    try:
        return dictionary['name']
    except:
        return 'Not_specified'

# Фунция возвращает список опций в комплектации
def get_eqp_options(dictionary):
    try:
        return list(dictionary.keys())
    except:
        return None

# Фунция возвращает кол-во опций в комплектации
def get_eqp_amount(eqp_list):
    try:
        return len(eqp_list)
    except:
        return 0

# Фунция возвращает ценовой сегмент
def get_price_segment(dictionary):
    try:
        return dictionary['price_segment']
    except:
        return 'Not_specified'

# Фунция возвращает время владения в месяцах
def get_own_time(string):
    months = 0
    if type(string) == str:
        numbers = re.findall(r'\d+', string)
        if len(numbers) == 2:
            months += int(numbers[0])*12 + int(numbers[1])
        else:
            if 'месяц' in string:
                months += int(numbers[0])
            else:
                months += int(numbers[0])*12
    return months

# Фунция возвращает цену в рублях
def get_rur_price(dictionary):
    try:
        return dictionary['RUR']
    except:
        return None

# Фунция возвращает цену в евро
def get_eur_price(dictionary):
    try:
        return dictionary['EUR']
    except:
        return None

# Фунция возвращает цену в долларах
def get_usd_price(dictionary):
    try:
        return dictionary['USD']
    except:
        return None

# %% [markdown]
# Обработка:

# %%
# Извлечение информации из словарей
data['comp_id'] = data['complectation_dict'].apply(get_comp_id)
data['comp_name'] = data['complectation_dict'].apply(get_comp_name)
data['eqp_options'] = data['equipment_dict'].apply(get_eqp_options)
data['eqp_amount'] = data['eqp_options'].apply(get_eqp_amount)
data['price_segment'] = data['super_gen'].apply(get_price_segment)
data['gen_id'] = data['super_gen'].apply(lambda x: x['id'])
data['rur_price'] = data['price_info'].apply(get_rur_price)
data['eur_price'] = data['price_info'].apply(get_eur_price)
data['usd_price'] = data['price_info'].apply(get_usd_price)

# Извлечение информации из строк
data['eng_volume'] = data['engineDisplacement'].apply(lambda x: float('0'+x[:str.find(x,' ')]))
data['eng_pwr'] = data['enginePower'].apply(lambda x: int(x[:str.find(x,' ')]))
data['own_time'] = data['Владение'].apply(get_own_time)

# Даты
data['parsing_datetime'] = pd.to_datetime(data['parsing_unixtime'],unit='s')

# Правки
data['Владельцы'] = data['Владельцы'].str.replace('\xa0',' ')

# Удаление
data.drop(['car_url','complectation_dict','engineDisplacement',
           'enginePower', 'equipment_dict', 'image','model_info',
           'name', 'priceCurrency','super_gen','vehicleConfiguration',
           'Владение', 'Состояние', 'Таможня', 'price_info'], 
          axis=1, inplace = True)

# %%
data.sample(5)
# Out:
#                  bodyType     brand       color  \
# 19453   внедорожник 5 дв.      AUDI       белый
# 3307                седан     VOLVO  фиолетовый
# 102211  внедорожник 5 дв.    TOYOTA      чёрный
# 84971               седан      AUDI      чёрный
# 52556       хэтчбек 3 дв.  MERCEDES     красный
#
#                                               description fuelType   mileage  \
# 19453   Официальный дилер BMW в г. Краснодаре, компани...   дизель   91370.0
# 3307                                               Продаю   бензин   50000.0
# 102211  Автомобиль от официального дилера HONDA, SUZUK...   дизель  650000.0
# 84971   Личный автомобиль чёрного цвета коих мало.в се...   бензин  197000.0
# 52556   Аккуратный, удобный авто немецкого качества го...   бензин  130000.0
#
#         modelDate          model_name  numberOfDoors  parsing_unixtime  \
# 19453      2015.0                  Q7            5.0        1619963696
# 3307       1994.0                 960            4.0        1619702803
# 102211     2002.0  LAND_CRUISER_PRADO            5.0        1603294584
# 84971      2007.0                  A4            4.0        1603127799
# 52556      2004.0            A_KLASSE            3.0        1620197013
#
#         productionDate       sell_id vehicleTransmission    vendor  \
# 19453           2015.0  1.102738e+09      автоматическая  EUROPEAN
# 3307            1997.0  1.087404e+09      автоматическая  EUROPEAN
# 102211          2004.0  1.101302e+09      автоматическая  JAPANESE
# 84971           2010.0  1.096428e+09            вариатор  EUROPEAN
# 52556           2006.0  1.103105e+09            вариатор  EUROPEAN
#
#           Владельцы       ПТС    Привод   Руль  train   comp_id  \
# 19453   3 или более  Дубликат    полный  Левый      1  20943688
# 3307    3 или более  Оригинал    задний  Левый      1         0
# 102211   1 владелец  Оригинал    полный  Левый      0         0
# 84971   3 или более  Дубликат  передний  Левый      0         0
# 52556   2 владельца  Оригинал  передний  Левый      1         0
#
#             comp_name                                        eqp_options  \
# 19453           Sport  [cruise-control, esp, usb, sport-seats, multi-...
# 3307    Not_specified                                                 []
# 102211  Not_specified  [electro-window-front, audiosystem-tv, roof-ra...
# 84971   Not_specified  [cruise-control, tinted-glass, esp, eco-leathe...
# 52556   Not_specified  [engine-proof, alloy-wheel-disks, 16-inch-whee...
#
#         eqp_amount  price_segment    gen_id  rur_price  eur_price  usd_price  \
# 19453           61        PREMIUM  20368749  3225000.0    35602.0    43089.0
# 3307             0         MEDIUM  20275639   200000.0     2218.0     2689.0
# 102211          26  Not_specified  20398997        0.0        0.0        0.0
# 84971           63  Not_specified   2324133        0.0        0.0        0.0
# 52556           19        PREMIUM   4601810   349000.0     3858.0     4637.0
#
#         eng_volume  eng_pwr  own_time    parsing_datetime
# 19453          3.0      249         0 2021-05-02 13:54:56
# 3307           2.5      170         0 2021-04-29 13:26:43
# 102211         3.0      166       194 2020-10-21 15:36:24
# 84971          1.8      160         0 2020-10-19 17:16:39
# 52556          1.5       95        28 2021-05-05 06:43:33

# %%
# Проверка на наличие целевой переменной
data[data.rur_price.isna()==True]
# Out:
#                 bodyType   brand        color  \
# 17               лифтбек   SKODA       чёрный
# 21               лифтбек   SKODA   коричневый
# 43               лифтбек   SKODA        белый
# 64       универсал 5 дв.   SKODA        синий
# 120    внедорожник 5 дв.   SKODA        серый
# ...                  ...     ...          ...
# 80970              седан  TOYOTA   золотистый
# 80990              седан  TOYOTA  серебристый
# 80996              седан  TOYOTA        серый
# 81012              седан  TOYOTA        белый
# 81022              седан  TOYOTA        синий
#
#                                              description fuelType   mileage  \
# 17     Ваш выбор и Ваше время — наши главные приорите...   бензин  149500.0
# 21     Автомобиль куплен в январе 2020 года у оф. дил...   бензин   16500.0
# 43     Как человек, поездивший на множестве авто, зая...   бензин  132000.0
# 64     #cme1039-№2918-11210020a5bb11ebae4730e17163fbd...   бензин  171363.0
# 120    Автомобиль продается от официального дилерског...   бензин  164193.0
# ...                                                  ...      ...       ...
# 80970  Год выпуска: 2000. Пробег: 150 000 км. Кузов: ...   бензин  150000.0
# 80990  Продаю надёжного японца. 2 владельца по птс. П...   бензин  223000.0
# 80996  ПТС оригинал, выдан Владивостокской таможней, ...   бензин  100550.0
# 81012  продам, в нармальном состоянии автомобиль двиг...   бензин  260000.0
# 81022  Автомобиль в хтс.двигатель после капитального ...   бензин  260000.0
#
#        modelDate model_name  numberOfDoors  parsing_unixtime  productionDate  \
# 17        2008.0    OCTAVIA            5.0        1619648639          2013.0
# 21        2017.0    OCTAVIA            5.0        1619648649          2020.0
# 43        2008.0     SUPERB            5.0        1619648705          2012.0
# 64        2008.0     SUPERB            5.0        1619648761          2012.0
# 120       2013.0       YETI            5.0        1619648883          2015.0
# ...          ...        ...            ...               ...             ...
# 80970     1999.0      PLATZ            4.0        1620371532          2000.0
# 80990     1999.0      PLATZ            4.0        1620371596          2000.0
# 80996     1999.0      PLATZ            4.0        1620371614          2002.0
# 81012     1999.0      PLATZ            4.0        1620371666          2001.0
# 81022     1999.0      PLATZ            4.0        1620371707          2000.0
#
#             sell_id vehicleTransmission    vendor    Владельцы       ПТС  \
# 17     1.102848e+09    роботизированная  EUROPEAN  3 или более  Оригинал
# 21     1.103226e+09      автоматическая  EUROPEAN   1 владелец  Оригинал
# 43     1.101742e+09      автоматическая  EUROPEAN   1 владелец  Оригинал
# 64     1.103342e+09    роботизированная  EUROPEAN   1 владелец  Оригинал
# 120    1.102816e+09    роботизированная  EUROPEAN  2 владельца  Оригинал
# ...             ...                 ...       ...          ...       ...
# 80970  1.101385e+09      автоматическая  JAPANESE  2 владельца  Оригинал
# 80990  1.101334e+09      автоматическая  JAPANESE  2 владельца  Оригинал
# 80996  1.103379e+09      автоматическая  JAPANESE  2 владельца  Оригинал
# 81012  1.103024e+09      автоматическая  JAPANESE  3 или более  Дубликат
# 81022  1.103248e+09      автоматическая  JAPANESE  3 или более  Оригинал
#
#          Привод    Руль  train   comp_id       comp_name  \
# 17     передний   Левый      1         0   Not_specified
# 21     передний   Левый      1  21403777  Hockey Edition
# 43     передний   Левый      1   2436032        Elegance
# 64     передний   Левый      1         0   Not_specified
# 120      полный   Левый      1  20805791        Ambition
# ...         ...     ...    ...       ...             ...
# 80970  передний  Правый      1         0   Not_specified
# 80990  передний  Правый      1         0   Not_specified
# 80996  передний  Правый      1         0   Not_specified
# 81012  передний  Правый      1         0   Not_specified
# 81022  передний  Правый      1         0   Not_specified
#
#                                              eqp_options  eqp_amount  \
# 17     [electro-window-back, asr, tinted-glass, leath...          22
# 21     [cruise-control, esp, adaptive-light, usb, mul...          66
# 43     [cruise-control, asr, esp, adaptive-light, usb...          66
# 64     [abs, rain-sensor, light-sensor, cruise-contro...          64
# 120    [abs, esp, asr, computer, rain-sensor, light-s...          26
# ...                                                  ...         ...
# 80970                                                 []           0
# 80990                                                 []           0
# 80996  [feedback-alarm, lock, audiosystem-cd, 12v-soc...          19
# 81012                                                 []           0
# 81022  [electro-window-front, condition, velvet-seats...          16
#
#       price_segment    gen_id  rur_price  eur_price  usd_price  eng_volume  \
# 17           MEDIUM   4560887        NaN        NaN        NaN         1.4
# 21           MEDIUM  20898195        NaN        NaN        NaN         1.6
# 43           MEDIUM   2309235        NaN        NaN        NaN         1.8
# 64           MEDIUM   2309235        NaN        NaN        NaN         2.0
# 120          MEDIUM  20078038        NaN        NaN        NaN         1.8
# ...             ...       ...        ...        ...        ...         ...
# 80970        MEDIUM   8302962        NaN        NaN        NaN         1.0
# 80990        MEDIUM   8302962        NaN        NaN        NaN         1.5
# 80996        MEDIUM   8302962        NaN        NaN        NaN         1.5
# 81012        MEDIUM   8302962        NaN        NaN        NaN         1.5
# 81022        MEDIUM   8302962        NaN        NaN        NaN         1.5
#
#        eng_pwr  own_time    parsing_datetime
# 17         122         0 2021-04-28 22:23:59
# 21         110        15 2021-04-28 22:24:09
# 43         152       102 2021-04-28 22:25:05
# 64         200         0 2021-04-28 22:26:01
# 120        152         0 2021-04-28 22:28:03
# ...        ...       ...                 ...
# 80970       70         0 2021-05-07 07:12:12
# 80990      110       201 2021-05-07 07:13:16
# 80996      110         0 2021-05-07 07:13:34
# 81012      110         0 2021-05-07 07:14:26
# 81022      110         0 2021-05-07 07:15:07
#
# [4188 rows x 32 columns]

# %%
# Проверка на то, что целевая пропущена только в тренировочной выборке
data[data.rur_price.isna()==True].train.unique()
# Out:
# array([1])

# %%
# Удаление пропущенных значений
data.dropna(subset=['rur_price'], axis=0, inplace = True)

# %% [markdown]
# ### Добавление старой тренировочной выборки

# %%
# Загрузка данных в переменные
# DIR_OLD_TRAIN   = '../input/parsing-all-moscow-auto-ru-09-09-2020/'
# old_train = pd.read_csv(DIR_OLD_TRAIN+'all_auto_ru_09_09_2020.csv')
old_train = pd.read_csv('all_auto_ru_09_09_2020.csv')

# %%
pd.options.display.max_columns = old_train.shape[1]
old_train.head(3)
# Out:
#           bodyType brand   color fuelType  modelDate                   name  \
# 0            Седан  AUDI  040001   бензин     1990.0  2.8 MT (174 л.с.) 4WD
# 1            Седан  AUDI  EE1D19   бензин     1982.0       1.8 MT (90 л.с.)
# 2  Универсал 5 дв.  AUDI  0000CC   бензин     1988.0  2.3 MT (136 л.с.) 4WD
#
#    numberOfDoors  productionDate          vehicleConfiguration  \
# 0            4.0            1991          SEDAN MECHANICAL 2.8
# 1            4.0            1986          SEDAN MECHANICAL 1.8
# 2            5.0            1989  WAGON_5_DOORS MECHANICAL 2.3
#
#   vehicleTransmission engineDisplacement  enginePower  \
# 0          MECHANICAL                2.8        174.0
# 1          MECHANICAL                1.8         90.0
# 2          MECHANICAL                2.3        136.0
#
#                                          description  mileage Комплектация  \
# 0   Машина  в приличном состоянии ,не гнилая не р...   350000  {'id': '0'}
# 1  Машина в оригинале не гнилая все вопросы по те...   173424  {'id': '0'}
# 2  ПТС Оригинал!\nПолный комплект ключей!\nПо рез...   230000  {'id': '0'}
#
#      Привод  Руль  Состояние  Владельцы       ПТС  Таможня Владение     price  \
# 0    полный  LEFT        NaN        3.0  ORIGINAL     True      NaN  200000.0
# 1  передний  LEFT        NaN        3.0  ORIGINAL     True      NaN   60000.0
# 2    полный  LEFT        NaN        3.0  ORIGINAL     True      NaN   99000.0
#
#              start_date  hidden model
# 0  2019-10-03T08:09:11Z     NaN   100
# 1  2020-09-06T06:49:40Z     NaN   100
# 2  2020-09-02T14:04:21Z     NaN   100

# %%
# Проверка на избыточность брендов в старой тренировочной выборке
len(old_train.brand.unique()) - len(for_parsing.brand.unique())
# Out:
# 24

# %%
# Очистка
useful_brands = for_parsing.brand.unique()
for_processing = old_train[old_train.brand == useful_brands[0]]
for brand in tqdm(useful_brands[1:]):
    for_processing = for_processing.append(old_train[old_train.brand == brand], sort=False).reset_index(drop=True)
old_train = for_processing
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11.0), HTML(value='')))

# %%
# Проверка на избыточность брендов в старой тренировочной выборке
len(old_train.brand.unique()) - len(for_parsing.brand.unique())
# Out:
# 0

# %% [markdown]
# Время парсинга (предположительно start_date):

# %%
# Преобразование в datetime
old_train['start_date'] = old_train.start_date.progress_apply(lambda x: pd.to_datetime(x, infer_datetime_format=True))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=49309.0), HTML(value='')))

# %%
# Преобразование в unixtimestamp
old_train['parsing_unixtime'] = old_train.start_date.progress_apply(lambda x: x.value/(10**9))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=49309.0), HTML(value='')))

# %%
# Минимальное и максимальное значения
display(old_train[old_train.parsing_unixtime==old_train.parsing_unixtime.max()]['start_date'])
display(old_train[old_train.parsing_unixtime==old_train.parsing_unixtime.min()]['start_date'])
# Out:
# 30554    2020-09-09 10:38:32
# Name: start_date, dtype: object
# 1523    2014-06-10 06:27:00
# Name: start_date, dtype: object

# %% [markdown]
# Судя по разбросу в несколько лет, start_date - дата размещения объявления. В таком случае, время парсинга примерно равно дате размещения последнего объявления.

# %% [markdown]
# Преобразование параметров 'Комплектация' и 'Владение':

# %%
def get_dict(string):
    try:
        return ast.literal_eval(string)
    except:
        return None

# %%
# Преобразование
old_train['Комплектация'] = old_train['Комплектация'].apply(lambda x: ast.literal_eval(x))
old_train['Владение'] = old_train['Владение'].apply(get_dict)

# %% [markdown]
# #### Создание датафрейма в формате основных данных:

# %%
old_train.head(3)
# Out:
#         bodyType  brand   color fuelType  modelDate                  name  \
# 0          Седан  SKODA  FAFBFB   бензин     1969.0  100 1.0 MT (42 л.с.)
# 1      Седан 120  SKODA  C49648   бензин     1976.0      1.2 MT (53 л.с.)
# 2  Хэтчбек 5 дв.  SKODA  040001   бензин     2010.0      1.2 MT (70 л.с.)
#
#    numberOfDoors  productionDate              vehicleConfiguration  \
# 0            4.0            1976              SEDAN MECHANICAL 100
# 1            4.0            1984              SEDAN MECHANICAL 1.2
# 2            5.0            2012  HATCHBACK_5_DOORS MECHANICAL 1.2
#
#   vehicleTransmission engineDisplacement  enginePower  \
# 0          MECHANICAL                100         42.0
# 1          MECHANICAL                1.2         53.0
# 2          MECHANICAL                1.2         70.0
#
#                                          description  ...  Комплектация  \
# 0  На автомобиль получен новый ПТС, СТС и государ...  ...   {'id': '0'}
# 1  120L 52 л.с. в России таких нет! состояние отл...  ...   {'id': '0'}
# 2  Автомобиль по тех состоянию без нареканий. Куз...  ...   {'id': '0'}
#
#      Привод  Руль Состояние  Владельцы       ПТС Таможня  \
# 0    задний  LEFT       NaN        1.0  ORIGINAL    True
# 1    задний  LEFT       NaN        2.0  ORIGINAL    True
# 2  передний  LEFT       NaN        2.0  ORIGINAL    True
#
#                      Владение     price           start_date hidden  \
# 0  {'year': 1992, 'month': 2}  150000.0  2020-03-01 04:18:19    NaN
# 1  {'year': 2012, 'month': 4}  170000.0  2019-03-28 15:13:10    NaN
# 2  {'year': 2020, 'month': 2}  250000.0  2020-08-20 07:41:09    NaN
#
#         model parsing_unixtime
# 0  100_SERIES     1.583036e+09
# 1         120     1.553786e+09
# 2       FABIA     1.597909e+09
#
# [3 rows x 27 columns]

# %%
pd.options.display.max_columns = data.shape[1]
data.sample(3)
# Out:
#               bodyType   brand    color  \
# 94631            седан  NISSAN   чёрный
# 23552  универсал 5 дв.    AUDI   чёрный
# 2911     хэтчбек 5 дв.   VOLVO  голубой
#
#                                              description fuelType   mileage  \
# 94631   Очень надежный  автомобиль. Владею два года, ...   бензин  184000.0
# 23552  Авто приобретался в 2015 у официального дилера...   бензин  146000.0
# 2911   Отличный экономичный авто 5,6 расход. Ремонт к...   дизель  225000.0
#
#        modelDate      model_name  numberOfDoors  parsing_unixtime  \
# 94631     2006.0  ALMERA_CLASSIC            4.0        1603279100
# 23552     2011.0      A4_ALLROAD            5.0        1619981081
# 2911      2012.0          V40_CC            5.0        1619685346
#
#        productionDate       sell_id vehicleTransmission    vendor  \
# 94631          2007.0  1.090694e+09        механическая  JAPANESE
# 23552          2012.0  1.096852e+09    роботизированная  EUROPEAN
# 2911           2013.0  1.102184e+09    роботизированная  EUROPEAN
#
#          Владельцы       ПТС    Привод   Руль  train comp_id      comp_name  \
# 94631  3 или более  Оригинал  передний  Левый      0       0  Not_specified
# 23552  3 или более  Дубликат    полный  Левый      1       0  Not_specified
# 2911   2 владельца  Оригинал  передний  Левый      1       0  Not_specified
#
#                                              eqp_options  eqp_amount  \
# 94631                                               None           0
# 23552  [cruise-control, tinted-glass, esp, usb, sport...          54
# 2911                                                  []           0
#
#        price_segment   gen_id  rur_price  eur_price  usd_price  eng_volume  \
# 94631  Not_specified  2404949        0.0        0.0        0.0         1.6
# 23552        PREMIUM  7754720  1195000.0    13192.0    15966.0         2.0
# 2911         PREMIUM  8290942   765000.0     8460.0    10208.0         1.6
#
#        eng_pwr  own_time    parsing_datetime
# 94631      107         0 2020-10-21 11:18:20
# 23552      211        68 2021-05-02 18:44:41
# 2911       115         0 2021-04-29 08:35:46

# %%
# Фунция возвращает объем двигателя из name
def get_eng_pwr(string):
    try:
        liters = re.findall(r'\d+', string[:str.find(string,'.')])[-1]
        decimals = re.findall(r'\d+', string[str.find(string,'.'):])[0]
        return float(liters+'.'+decimals)
    except:
        return 0

# Фунция возвращает время владения в месяцах
def get_own_time(dictinonary):
    months = 0
    if type(dictinonary) == dict:
        months += (2020 - dictinonary['year'])*12
        months += (9 - dictinonary['month'])
    return months

# %%
# Обработка старой тренировочной выборки
adj_old_train = pd.DataFrame()
old_train['bodyType'] = old_train['bodyType'].apply(lambda x: str(x))
adj_old_train['bodyType'] = old_train['bodyType'].apply(lambda x: x.lower())
adj_old_train['brand'] = old_train['brand']

mapping_dict = {'040001':'чёрный', 'EE1D19':'красный', '0000CC':'синий', 
                'CACECB':'серебристый', '007F00':'зелёный', 'FAFBFB':'белый', 
                '97948F':'серый', '22A0F8':'голубой', '660099':'пурпурный', 
                '200204':'коричневый', 'C49648':'бежевый', 'DEA522':'золотистый', 
                '4A2197':'фиолетовый', 'FFD600':'жёлтый', 'FF8649':'оранжевый', 
                'FFC0CB':'розовый'}
adj_old_train['color'] = old_train['color'].map(mapping_dict)

for col in ['description', 'fuelType', 'mileage', 'modelDate']:
    adj_old_train[col] = old_train[col]
adj_old_train['model_name'] = old_train['model']
adj_old_train['numberOfDoors'] = old_train['numberOfDoors']
adj_old_train['parsing_unixtime'] = old_train['parsing_unixtime'].max()
adj_old_train['productionDate'] = old_train['productionDate']
adj_old_train['sell_id'] = None

mapping_dict = {'MECHANICAL':'механическая', 'AUTOMATIC':'автоматическая', 
                'ROBOT':'роботизированная', 'VARIATOR':'вариатор'}
adj_old_train['vehicleTransmission'] = old_train['vehicleTransmission'].map(mapping_dict)

mapping_series = data.groupby('brand').vendor.unique()
mapping_dict = {}
for brand in mapping_series.index:
    mapping_dict[brand] = mapping_series[brand][0]
adj_old_train['vendor'] = old_train['brand'].map(mapping_dict)

mapping_dict = {1.:'1 владелец', 2.:'2 владельца', 
                3.:'3 или более'}
adj_old_train['Владельцы'] = old_train['Владельцы'].map(mapping_dict)

mapping_dict = {'ORIGINAL':'Оригинал', 'DUPLICATE':'Дубликат'}
adj_old_train['ПТС'] = old_train['ПТС'].map(mapping_dict)

adj_old_train['Привод'] = old_train['Привод']

mapping_dict = {'LEFT':'Левый', 'RIGHT':'Правый'}
adj_old_train['Руль'] = old_train['Руль'].map(mapping_dict)

adj_old_train['train'] = 1

adj_old_train['comp_id'] = old_train['Комплектация'].apply(get_comp_id)
adj_old_train['comp_name'] = old_train['Комплектация'].apply(get_comp_name)
adj_old_train['eqp_options'] = None
adj_old_train['eqp_amount'] = None
adj_old_train['price_segment'] = None
adj_old_train['gen_id'] = None
adj_old_train['rur_price'] = old_train['price']
# Курсы валюты взяты вручную с сайта ЦБ РФ, т.к. не имеет смысла делать парсинг ради 2ух значений
adj_old_train['eur_price'] = old_train['price'].apply(lambda x: np.round(x/89.7369))
adj_old_train['usd_price'] = old_train['price'].apply(lambda x: np.round(x/75.9645))
adj_old_train['eng_volume'] = old_train['name'].apply(get_eng_pwr)
adj_old_train['eng_pwr'] = old_train['enginePower']
adj_old_train['own_time'] = old_train['Владение'].apply(get_own_time)
adj_old_train['parsing_datetime'] = pd.to_datetime(adj_old_train['parsing_unixtime'],unit='s')

# %%
adj_old_train.sample(3)
# Out:
#                 bodyType       brand   color  \
# 44977  внедорожник 5 дв.  VOLKSWAGEN   синий
# 1224             лифтбек       SKODA  чёрный
# 14285              седан         BMW  чёрный
#
#                                              description fuelType  mileage  \
# 44977  Автомобиль покупался для себя в США, перевозил...   бензин   252576
# 1224   Продажа а/м осуществляется ОФИЦИАЛЬНЫМ ДИЛЕРОМ...   бензин   167519
# 14285  Доброго времени суток ! Машина в эдиальном сос...   бензин   192000
#
#        modelDate model_name  numberOfDoors  parsing_unixtime  productionDate  \
# 44977     2002.0    TOUAREG            5.0      1.599648e+09            2005
# 1224      2008.0    OCTAVIA            5.0      1.599648e+09            2011
# 14285     2001.0        7ER            4.0      1.599648e+09            2003
#
#       sell_id vehicleTransmission    vendor    Владельцы       ПТС    Привод  \
# 44977    None      автоматическая  EUROPEAN  2 владельца  Оригинал    полный
# 1224     None    роботизированная  EUROPEAN  2 владельца  Оригинал  передний
# 14285    None      автоматическая  EUROPEAN  3 или более  Дубликат    задний
#
#         Руль  train comp_id      comp_name eqp_options eqp_amount  \
# 44977  Левый      1       0  Not_specified        None       None
# 1224   Левый      1       0  Not_specified        None       None
# 14285  Левый      1       0  Not_specified        None       None
#
#       price_segment gen_id  rur_price  eur_price  usd_price  eng_volume  \
# 44977          None   None   550000.0     6129.0     7240.0         3.2
# 1224           None   None   485000.0     5405.0     6385.0         1.8
# 14285          None   None   650000.0     7243.0     8557.0         3.6
#
#        eng_pwr  own_time    parsing_datetime
# 44977    241.0       123 2020-09-09 10:38:32
# 1224     152.0         0 2020-09-09 10:38:32
# 14285    272.0         0 2020-09-09 10:38:32

# %%
# Проверка, что столбцы совпадают с основным датасетом
cols_check = []
for i in range(len(data.columns)):
    cols_check.append(data.columns[i]==adj_old_train.columns[i])
print(np.unique(cols_check))
# Out:
# [ True]

# %%
# Очистка от пропусков
adj_old_train.dropna(inplace=True, subset=['description', 'modelDate', 'numberOfDoors', 
                                           'vehicleTransmission', 'Привод', 'rur_price', 
                                           'eur_price', 'usd_price', 'eng_pwr'])

na_values(adj_old_train)
# Out:
# SELL_ID
# %% пропущенных данных в столбце: 	100.0
# (%% от общего кол-ва данных: 	3.0)
#
# ВЛАДЕЛЬЦЫ
# %% пропущенных данных в столбце: 	23.0
# (%% от общего кол-ва данных: 	1.0)
#
# ПТС
# %% пропущенных данных в столбце: 	1.0
# (%% от общего кол-ва данных: 	0.0)
#
# EQP_OPTIONS
# %% пропущенных данных в столбце: 	100.0
# (%% от общего кол-ва данных: 	3.0)
#
# EQP_AMOUNT
# %% пропущенных данных в столбце: 	100.0
# (%% от общего кол-ва данных: 	3.0)
#
# PRICE_SEGMENT
# %% пропущенных данных в столбце: 	100.0
# (%% от общего кол-ва данных: 	3.0)
#
# GEN_ID
# %% пропущенных данных в столбце: 	100.0
# (%% от общего кол-ва данных: 	3.0)

# %% [markdown]
# Внесение в основной датасет:

# %%
# Объединение выборок
data = data.append(adj_old_train, sort=False).reset_index(drop=True)

# %% [markdown]
# Доля тренировочной выборки в итоговом датасете:

# %%
np.round(data[data.train==1].shape[0]/data.shape[0],2)
# Out:
# 0.78

# %% [markdown]
# Разметка переменных:

# %%
# Предварительная разметка
bin_cols = []
cat_cols = []
dat_cols = []
num_cols = []

for column in data.drop('eqp_options', axis=1).columns:
    if len(data[column].unique()) == 2:
        bin_cols.append(column)
    elif data[column].dtype == 'datetime64[ns]':
        dat_cols.append(column)
    elif (data[column].dtype == float)|(data[column].dtype == int):
        num_cols.append(column)
    else:
        cat_cols.append(column)

print('Бинарные данные: \t', bin_cols)
print()
print('Категориальные данные: \t', cat_cols)
print()
print('Время/дата: \t\t', dat_cols)
print()
print('Числовые данные: \t', num_cols)
# Out:
# Бинарные данные: 	 ['vendor', 'Руль', 'train']
#
# Категориальные данные: 	 ['bodyType', 'brand', 'color', 'description', 'fuelType', 'model_name', 'sell_id', 'vehicleTransmission', 'Владельцы', 'ПТС', 'Привод', 'comp_id', 'comp_name', 'eqp_amount', 'price_segment', 'gen_id']
#
# Время/дата: 		 ['parsing_datetime']
#
# Числовые данные: 	 ['mileage', 'modelDate', 'numberOfDoors', 'parsing_unixtime', 'productionDate', 'rur_price', 'eur_price', 'usd_price', 'eng_volume', 'eng_pwr', 'own_time']

# %%
# Метка тренировочной выборки не является бинарным признаком
bin_cols.remove('train')

# Текстовые переменные (description, eqp_options) будут обработаны отдельно
# ID авто необходимо только для submission
for col in ['description', 'sell_id']:
    cat_cols.remove(col)

# %% [markdown]
# # Наивная модель

# %% [markdown]
# Для промежуточного моделирования будет использован алгоритм CatBoost по следующим причинам:
# - Алгоритм работает с пропусками в данных
# - Показывает высокую эффективность на категориальных данных, которых в датасете большинство
# - Не требует предобработки категориальных переменных
# - Низкий разброс результатов, что позволяет использовать алгоритм с дефолтными гиперпараметрами

# %%
# Функция возвращает метрики для данных и модели
def metics(data, target, model=CatBoostRegressor(random_seed = RS, silent=True)):
    df = data.copy()
    
    # Кодирование
    LE = LabelEncoder()
    for col in bin_cols+cat_cols:
        if df[col].dtype == object:
            df[col] = df[col].fillna('Non_specified')
            df[col] = df[col].apply(lambda x: str(x))
            df[col] = LE.fit_transform(df[col])
    
    # Разделение переменных
    X = df[sorted(bin_cols+cat_cols+num_cols)].drop(['rur_price', 'eur_price', 'usd_price'], axis=1).values
    y = df[target].values
    
    # Создание списков для записи локальных результатов
    local_mape = []
    local_mae = []
    local_mse = []
    
    # Моделирование с 3-ой кросс-валидацией
    SKF = StratifiedKFold(n_splits=3, shuffle=True, random_state=RS)
    for train_index, test_index in SKF.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        model.fit(X_train, y_train)
        preds = model.predict(X_test)
        local_mape.append(MAPE(y_test, preds))
        local_mae.append(mean_absolute_error(y_test, preds))
        local_mse.append(mean_squared_error(y_test, preds)**(1/2))
    
    # Усреднение метрик
    result = []
    result.append(np.mean(local_mape))
    result.append(np.mean(local_mae))
    result.append(np.mean(local_mse))
    
    return result

# %%
pd.set_option('display.float_format', lambda x: '%.4f' % x)

results = pd.DataFrame({'naive': metics(data[data.train==1], 'rur_price')}, 
                       index = ['MAPE','MAE','RMSE'])
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            naive
# MAPE      0.1744
# MAE  150333.7260
# RMSE 443434.7237

# %% [markdown]
# Наивная модель в среднем ошибается на 17.43%(MAPE) или на 150 100 руб(MAE). Вместе с тем отклонение квадратного кореня из среднеквадратичной ошибки (RMSE) выше среднего более чем в 2 раза, что говорит о том, что модель особенно плохо предсказывает некоторые примеры.

# %% [markdown]
# ## Выбор целевой

# %%
# Функция возвращает визуализацию результатов
def plot_results(results, target_metric):
    MMS = MinMaxScaler()
    trans_res = results.T
    scaled_res = pd.DataFrame(MMS.fit_transform(trans_res), 
                              columns=trans_res.columns, index=trans_res.index)
    
    fig, axs = plt.subplots(figsize=(15, 7), gridspec_kw={'height_ratios': [5, 1]}, nrows=2)
    sns.lineplot(x=results.columns, y=results.loc[target_metric].values, 
                 marker='o', sort = False, ax=axs[0])
    axs[0].set(ylabel=target_metric, xlabel='ITER')
    sns.lineplot(data = scaled_res, marker='o', 
                          sort = False, palette='viridis', ax=axs[1])
    plt.legend(loc='upper left')
    axs[1].set(ylabel='All Metrics', xlabel='ITER')
    plt.show()

# %%
# Расчет и запись метрик
results['eur_target'] = metics(data[data.train==1], 'eur_price')
results['usd_target'] = metics(data[data.train==1], 'usd_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            naive  eur_target  usd_target
# MAPE      0.1744      0.1738      0.1740
# MAE  150333.7260   1664.7240   1996.3549
# RMSE 443434.7237   4951.5050   5853.0802

# %% [markdown]
# По-видимому, наименее волатильна цена в евро. Это и будет целевой переменной, которую при финальном предсказании перевернем в рубль.

# %%
# Удаление промежуточных шагов
results.drop(['naive', 'eur_target', 'usd_target'], axis=1, inplace=True)

# Расчет и запись метрик
results['target_set'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set
# MAPE      0.1738
# MAE    1664.7240
# RMSE   4951.5050

# %% [markdown]
# # EDA

# %% [markdown]
# ## Бинарные данные

# %%
# Функция, проверяющая наличие статистически значимых различий между вариациями признака
def get_stat_dif(df, col, target):
    variations=len(df[col].value_counts().index)
    indexes=[i for i in range (0,variations)]
    comb=list(combinations(indexes, 2))
    for c in comb:
        x = df[df[col] == df[col].value_counts().index[c[0]]][target]
        y = df[df[col] == df[col].value_counts().index[c[1]]][target]
        t_test = weightstats.ttest_ind(x, y, usevar='unequal')
        if t_test[1] <= 0.05/len(comb):
            return True
        else:
            return False

# %%
# Функция выводит основную информацию, визуализацию пропорций в тренировочной выборке и сравнение с тестовой
def sum_up_cat(df, col, target, label='train'):
    print(col.upper())
    train = df[df[label]==1]
    trn = train[col].value_counts(normalize=True)
    tst = df[df[label]==0][col].value_counts(normalize=True)
    vc = train[col].value_counts()
    changes = pd.DataFrame({'train':trn, 'test':tst})
    for i in vc.index:
        print('{} (%%):\t{}'.format(i, np.round(trn[i],2)))
        print('\t Среднее значение целевой:\t{}'.format(np.round(train[train[col] == i][target].mean(),2)))
    print('Cтатистически значимые различия:\t{}'.format(get_stat_dif(train, col, target)))
    fig, axs = plt.subplots(figsize=(15, 5), ncols=2)
    sns.barplot(x=vc.index, y=vc.values, palette='viridis', ax=axs[0])
    if len(train[col].unique())>5:
        axs[0].tick_params(labelrotation=45)
    sns.lineplot(data=changes, palette='viridis', linewidth=3, ax=axs[1])
    if len(changes.index)>5:
        axs[1].tick_params(labelrotation=45)
    plt.show()

# %%
for column in bin_cols:
    sum_up_cat(data, column, 'eur_price')
# Out:
# VENDOR
# EUROPEAN (%%):	0.53
# 	 Среднее значение целевой:	20116.2
# JAPANESE (%%):	0.47
# 	 Среднее значение целевой:	10384.05
# Cтатистически значимые различия:	True
# РУЛЬ
# Левый (%%):	0.85
# 	 Среднее значение целевой:	17429.52
# Правый (%%):	0.15
# 	 Среднее значение целевой:	4385.73
# Cтатистически значимые различия:	True

# %% [markdown]
# Для данных переменных найдены статистически значимые различия.
#
# В тренировочной выборке больше авто с правым рулем японских производителей по сравнению с тестовой.

# %% [markdown]
# ## Категориальные данные

# %%
# Переменные, для которых уникальных значений меньше 15ти.
for column in cat_cols:
    if len(data[column].unique())<=15:
        sum_up_cat(data, column, 'eur_price')
# Out:
# BRAND
# NISSAN (%%):	0.15
# 	 Среднее значение целевой:	7551.08
# TOYOTA (%%):	0.15
# 	 Среднее значение целевой:	11246.55
# MERCEDES (%%):	0.13
# 	 Среднее значение целевой:	32496.76
# BMW (%%):	0.11
# 	 Среднее значение целевой:	25374.96
# VOLKSWAGEN (%%):	0.11
# 	 Среднее значение целевой:	11000.91
# AUDI (%%):	0.08
# 	 Среднее значение целевой:	14753.65
# MITSUBISHI (%%):	0.08
# 	 Среднее значение целевой:	8753.73
# SKODA (%%):	0.05
# 	 Среднее значение целевой:	8454.95
# HONDA (%%):	0.05
# 	 Среднее значение целевой:	6416.85
# VOLVO (%%):	0.04
# 	 Среднее значение целевой:	15418.96
# LEXUS (%%):	0.03
# 	 Среднее значение целевой:	26244.29
# INFINITI (%%):	0.02
# 	 Среднее значение целевой:	17176.77
# Cтатистически значимые различия:	True
# FUELTYPE
# бензин (%%):	0.8
# 	 Среднее значение целевой:	13042.44
# дизель (%%):	0.18
# 	 Среднее значение целевой:	26570.64
# гибрид (%%):	0.01
# 	 Среднее значение целевой:	13493.66
# электро (%%):	0.0
# 	 Среднее значение целевой:	16407.66
# газ (%%):	0.0
# 	 Среднее значение целевой:	6480.18
# Cтатистически значимые различия:	True
# VEHICLETRANSMISSION
# автоматическая (%%):	0.57
# 	 Среднее значение целевой:	19472.44
# механическая (%%):	0.21
# 	 Среднее значение целевой:	5504.71
# вариатор (%%):	0.12
# 	 Среднее значение целевой:	12504.0
# роботизированная (%%):	0.1
# 	 Среднее значение целевой:	17453.02
# Cтатистически значимые различия:	True
# ВЛАДЕЛЬЦЫ
# 3 или более (%%):	0.52
# 	 Среднее значение целевой:	7649.55
# 1 владелец (%%):	0.25
# 	 Среднее значение целевой:	21935.05
# 2 владельца (%%):	0.24
# 	 Среднее значение целевой:	14564.71
# Cтатистически значимые различия:	True
# ПТС
# Оригинал (%%):	0.85
# 	 Среднее значение целевой:	16930.6
# Дубликат (%%):	0.15
# 	 Среднее значение целевой:	7006.02
# Cтатистически значимые различия:	True
# ПРИВОД
# передний (%%):	0.45
# 	 Среднее значение целевой:	7201.55
# полный (%%):	0.44
# 	 Среднее значение целевой:	24983.22
# задний (%%):	0.11
# 	 Среднее значение целевой:	12411.62
# Cтатистически значимые различия:	True
# PRICE_SEGMENT
# MEDIUM (%%):	0.53
# 	 Среднее значение целевой:	7638.44
# PREMIUM (%%):	0.4
# 	 Среднее значение целевой:	22052.58
# ECONOMY (%%):	0.08
# 	 Среднее значение целевой:	4750.17
# Cтатистически значимые различия:	True

# %% [markdown]
# Для данных переменных найдены статистически значимые различия.
#
# Доля японских брендов выше в тренировочной выборке. В остальном, пропорции распределения схожи. За исключением ценового сегмента, который отсутствует в тестовой выборке. Имеет смысл удалить признак.

# %%
data[data.train==0].price_segment.unique()
# Out:
# array(['Not_specified'], dtype=object)

# %%
# Удаление
data.drop('price_segment', axis=1, inplace=True)
cat_cols.remove('price_segment')

# Расчет и запись метрик
results['drop_p_seg'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  drop_p_seg
# MAPE      0.1738      0.1746
# MAE    1664.7240   1674.1179
# RMSE   4951.5050   5006.9795

# %% [markdown]
# После удаления price_segment, качество модели снизилось.
#
# В любом случае, данная переменная не несет ценности для предсказаний на тестовой выборке.

# %%
# Проверка наличия статистически значимых различий для переменных с большим числом уникальных значений
for column in cat_cols:
    if len(data[column].unique())>15:
        print(column.upper())
        print('Cтатистически значимые различия:\t{}'.format(get_stat_dif(data[data.train==1], column, 'eur_price')))
# Out:
# BODYTYPE
# Cтатистически значимые различия:	True
# COLOR
# Cтатистически значимые различия:	True
# MODEL_NAME
# Cтатистически значимые различия:	True
# COMP_ID
# Cтатистически значимые различия:	True
# COMP_NAME
# Cтатистически значимые различия:	False
# EQP_AMOUNT
# Cтатистически значимые различия:	False
# GEN_ID
# Cтатистически значимые различия:	True

# %% [markdown]
# Статистически значимые различия не найдены для наименования комплектации и кол-ва опций.
#
# Необходимо проверить полезность данных переменных для модели.

# %%
# Исключение comp_name
cat_cols.remove('comp_name')

# Расчет и запись метрик
results['drop_c_nm'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  drop_p_seg  drop_c_nm
# MAPE      0.1738      0.1746     0.1743
# MAE    1664.7240   1674.1179  1675.0652
# RMSE   4951.5050   5006.9795  4941.1828

# %% [markdown]
# Удаление comp_name привело к снижению метрик.
#
# К тому же, comp_name дублировал comp_id и не несет большой ценности.

# %%
# Исключение eqp_amount
cat_cols.remove('eqp_amount')

# Расчет и запись метрик
results['drop_eq_a'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  drop_p_seg  drop_c_nm  drop_eq_a
# MAPE      0.1738      0.1746     0.1743     0.1747
# MAE    1664.7240   1674.1179  1675.0652  1676.8848
# RMSE   4951.5050   5006.9795  4941.1828  5026.4531

# %% [markdown]
# Несмотря на снижение вспомогательных метрик, удаление eqp_amount привело к повышению MAPE

# %%
cat_cols.append('eqp_amount')

# %% [markdown]
# ### Итог:

# %%
# Удаление промежуточных шагов
results.drop(['drop_p_seg', 'drop_c_nm', 'drop_eq_a'], axis=1, inplace=True)

# Расчет и запись метрик
results['post_cat'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat
# MAPE      0.1738    0.1743
# MAE    1664.7240 1675.0652
# RMSE   4951.5050 4941.1828

# %% [markdown]
# В ходе обработки метрики выросли. Во многом, из-за удаления признака, отсутвующего в тестовой выборке.

# %% [markdown]
# ## Числовые данные

# %%
# Функция рассчитывает кол-во выбросов по столбцам и их долю
def outbursts(df, col):
    Q25 = df[col].quantile(0.25)
    Q75 = df[col].quantile(0.75)
    IQR = Q75 - Q25
    lowest = Q25 - 1.5*IQR
    highest = Q75 + 1.5*IQR
    amount = df[(df[col] < lowest)|(df[col] > highest)].count()[0]
    ratio = amount/df.shape[0]
    return amount, ratio, lowest, highest

# %%
# Функция выводит основную информацию и график признака
def sum_up_num(df, col, target, label='train'):
    print(col.upper())
    train = df[df[label]==1]
    trn = train[col].describe()[1:]
    tst = df[df[label]==0][col].describe()[1:]
    changes = pd.DataFrame({'train':trn, 'test':tst})
    
    print(trn)
    print('Кол-во выбросов: {} \t (%%: {})'.format(outbursts(train, col)[0], 
                                                   np.round(outbursts(train, col)[1]*100,2)))
    print()
    fig, axs = plt.subplots(figsize=(20, 5), ncols=3)
    sns.distplot(train[col], kde=True, ax=axs[0])
    sns.boxplot(data = train,  x = col, palette = 'viridis', ax=axs[1])
    sns.lineplot(data=changes, palette='viridis', linewidth=3, ax=axs[2])
    plt.show()

# %%
for column in num_cols:
    sum_up_num(data, column, 'eur_price')
# Out:
# MILEAGE
# mean    157209.3194
# std     113238.1584
# min          0.0000
# 25%      74000.0000
# 50%     147100.0000
# 75%     222463.0000
# max    1000000.0000
# Name: mileage, dtype: float64
# Кол-во выбросов: 1859 	 (%%: 1.49)
# MODELDATE
# mean   2006.8681
# std       8.7029
# min    1904.0000
# 25%    2002.0000
# 50%    2009.0000
# 75%    2013.0000
# max    2020.0000
# Name: modelDate, dtype: float64
# Кол-во выбросов: 2226 	 (%%: 1.79)
# NUMBEROFDOORS
# mean   4.4927
# std    0.6766
# min    0.0000
# 25%    4.0000
# 50%    5.0000
# 75%    5.0000
# max    5.0000
# Name: numberOfDoors, dtype: float64
# Кол-во выбросов: 3520 	 (%%: 2.83)
# PARSING_UNIXTIME
# mean   1612257887.6844
# std       9918238.2175
# min    1599647912.0000
# 25%    1599647912.0000
# 50%    1619952959.0000
# 75%    1620116507.0000
# max    1620371710.0000
# Name: parsing_unixtime, dtype: float64
# Кол-во выбросов: 0 	 (%%: 0.0)
# PRODUCTIONDATE
# mean   2009.0580
# std       8.3761
# min    1904.0000
# 25%    2004.0000
# 50%    2011.0000
# 75%    2015.0000
# max    2021.0000
# Name: productionDate, dtype: float64
# Кол-во выбросов: 1452 	 (%%: 1.17)
# RUR_PRICE
# mean    1398001.2830
# std     1857453.8315
# min       20000.0000
# 25%      389000.0000
# 50%      800000.0000
# 75%     1729000.0000
# max    68500000.0000
# Name: rur_price, dtype: float64
# Кол-во выбросов: 9075 	 (%%: 7.3)
# EUR_PRICE
# mean    15530.4890
# std     20656.9367
# min       221.0000
# 25%      4305.0000
# 50%      8845.0000
# 75%     19197.0000
# max    763343.0000
# Name: eur_price, dtype: float64
# Кол-во выбросов: 9041 	 (%%: 7.27)
# USD_PRICE
# mean    18551.6874
# std     24580.6659
# min       263.0000
# 25%      5134.0000
# 50%     10593.0000
# 75%     22905.0000
# max    901737.0000
# Name: usd_price, dtype: float64
# Кол-во выбросов: 9028 	 (%%: 7.26)
# ENG_VOLUME
# mean     2.3320
# std      1.5224
# min      0.0000
# 25%      1.6000
# 50%      2.0000
# 75%      2.9000
# max    300.0000
# Name: eng_volume, dtype: float64
# Кол-во выбросов: 3359 	 (%%: 2.7)
# ENG_PWR
# mean   181.9853
# std     88.6240
# min     30.0000
# 25%    117.0000
# 50%    156.0000
# 75%    224.0000
# max    800.0000
# Name: eng_pwr, dtype: float64
# Кол-во выбросов: 4598 	 (%%: 3.7)
# OWN_TIME
# mean    14.9193
# std     33.7430
# min      0.0000
# 25%      0.0000
# 50%      0.0000
# 75%     12.0000
# max    578.0000
# Name: own_time, dtype: float64
# Кол-во выбросов: 21169 	 (%%: 17.02)

# %%
# Корреляционная матрица
f, ax = plt.subplots(figsize=(15, 12))
sns.heatmap(data[num_cols].corr(), vmin=-1, vmax=1, annot=True, linewidths=.5, cmap='viridis')

# %% [markdown]
# Числовые данные в тренировочной и тестовой выборках распределены примерно одинаково. Бросается в глаза, что в тестовой выборке минимальное кол-во дверей равно 0.
#
# Имеет смысл вычесть годы производства авто из текущего года, получив возраст. В таком случае распределение переменной будет выглядеть логнормально. Так же, вычитая из производства авто выпуск модели, мы получил кол-во лет перед производством. Это позволит избавиться от высокой корреляции.
#
# Мощность двигателя и пробег распределены логнормально. Имеет смысл нормализовать данные.
#
# Ожидаемо, цены на авто скореллированы между собой и имеют высокое кол-во выбросов в большую сторону. Дополнительная обработка входа и выхода, может улучшить предсказания модели. Указание цен в валюте может пригодиться для предсказания на тесте, так даты выгрузки данных отличаются. Возможно, цены в валюте ведут себя более стабильно.

# %% [markdown]
# ### Кол-во дверей

# %%
data[data.numberOfDoors==0]
# Out:
#          bodyType     brand  color  \
# 93780   кабриолет  MERCEDES  белый
# 142194  кабриолет  MERCEDES  белый
#
#                                               description fuelType    mileage  \
# 93780   на ходу. 1904 год. стоит в гараже, пылится.Кат...   бензин 48000.0000
# 142194  на ходу. 1904 год. стоит в гараже, пылится.Кат...   бензин 48000.0000
#
#         modelDate model_name  numberOfDoors  parsing_unixtime  productionDate  \
# 93780   1904.0000    SIMPLEX         0.0000   1603245843.0000       1904.0000
# 142194  1904.0000    SIMPLEX         0.0000   1599647912.0000       1904.0000
#
#                sell_id vehicleTransmission    vendor   Владельцы       ПТС  \
# 93780  1093802104.0000        механическая  EUROPEAN  1 владелец  Оригинал
# 142194            None        механическая  EUROPEAN  1 владелец  Оригинал
#
#         Привод    Руль  train comp_id      comp_name eqp_options eqp_amount  \
# 93780   задний  Правый      0       0  Not_specified        None          0
# 142194  задний  Правый      1       0  Not_specified        None       None
#
#           gen_id     rur_price   eur_price   usd_price  eng_volume  eng_pwr  \
# 93780   21743990        0.0000      0.0000      0.0000      5.3000  32.0000
# 142194      None 12000000.0000 133724.0000 157969.0000      5.3000  32.0000
#
#         own_time    parsing_datetime
# 93780         80 2020-10-21 02:04:03
# 142194        79 2020-09-09 10:38:32

# %% [markdown]
# Данное авто 1904-го года действительно не имеет дверей.

# %% [markdown]
# ### Года

# %%
data['age'] = data.parsing_datetime.dt.year - data.productionDate
data['years_in_prod'] = data.productionDate - data.modelDate

# %%
for column in ['age','years_in_prod']:
    sum_up_num(data, column, 'eur_price')
# Out:
# AGE
# mean    11.5599
# std      8.4898
# min      0.0000
# 25%      5.0000
# 50%     10.0000
# 75%     17.0000
# max    116.0000
# Name: age, dtype: float64
# Кол-во выбросов: 778 	 (%%: 0.63)
# YEARS_IN_PROD
# mean    2.1899
# std     1.7485
# min    -5.0000
# 25%     1.0000
# 50%     2.0000
# 75%     3.0000
# max    58.0000
# Name: years_in_prod, dtype: float64
# Кол-во выбросов: 2331 	 (%%: 1.87)

# %% [markdown]
# Бросается в глаза отрицательный показатель years_in_prod. Имеет смысл выяснить, характерна ли эта ошибка только для тренировочной выборки.

# %%
data[data['years_in_prod']<0].train.unique()
# Out:
# array([1, 0])

# %% [markdown]
# Авто, у которых дата производства меньше даты выпуска, присутствуют как в тренирочной, так и в тестовой выборках.

# %%
for column in ['age','years_in_prod']:
    num_cols.append(column)

# Расчет и запись метрик
results['age_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  age_added
# MAPE      0.1738    0.1743     0.1738
# MAE    1664.7240 1675.0652  1676.7070
# RMSE   4951.5050 4941.1828  4987.1651

# %% [markdown]
# В среднем, точность модели снизилась после добавления переменных

# %% [markdown]
# ### Нормализация

# %%
data['mileage_norm'] = data.mileage.apply(lambda x: np.log(x))
data['eng_pwr_norm'] = data.eng_pwr.apply(lambda x: np.log(x))

for column in ['mileage_norm','eng_pwr_norm']:
    num_cols.append(column)

# Расчет и запись метрик
results['norm_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  age_added  norm_added
# MAPE      0.1738    0.1743     0.1738      0.1745
# MAE    1664.7240 1675.0652  1676.7070   1677.4705
# RMSE   4951.5050 4941.1828  4987.1651   4946.9444

# %% [markdown]
# Нормализация не улучшает работу модели с точки зрения MAPE. Вместе с тем, корень среднеквадратичной ошибки снижается.
#
# В целом, так как алгоритм основан на деревьях решений, не чувствительных к выбросам, нет необходимости нормализовать переменные.

# %% [markdown]
# ### Доп. обработка целевой переменной

# %% [markdown]
# Добавление доп. обработки в функцию моделирования:

# %%
# Функция возвращает метрики для данных и модели
def metics(data, target, model=CatBoostRegressor(random_seed = RS, silent=True)):
    df = data.copy()
    
    # Кодирование
    LE = LabelEncoder()
    for col in bin_cols+cat_cols:
        if df[col].dtype == object:
            df[col] = df[col].fillna('Non_specified')
            df[col] = df[col].apply(lambda x: str(x))
            df[col] = LE.fit_transform(df[col])
    
    # Разделение переменных
    X = df[sorted(bin_cols+cat_cols+num_cols)].drop(['rur_price', 'eur_price', 'usd_price'], axis=1).values
    y = df[target].values
    
    # Создание списков для записи локальных результатов
    local_mape = []
    local_mae = []
    local_mse = []
    
    # Моделирование с 3-ой кросс-валидацией
    SKF = StratifiedKFold(n_splits=3, shuffle=True, random_state=RS)
    for train_index, test_index in SKF.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        model.fit(X_train, np.log(y_train)) #<= Логорифмирование
        preds = np.exp(model.predict(X_test)) #<= Экспонента
        local_mape.append(MAPE(y_test, preds))
        local_mae.append(mean_absolute_error(y_test, preds))
        local_mse.append(mean_squared_error(y_test, preds)**(1/2))
    
    # Усреднение метрик
    result = []
    result.append(np.mean(local_mape))
    result.append(np.mean(local_mae))
    result.append(np.mean(local_mse))
    
    return result

# %%
# Расчет и запись метрик
results['norm_target'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  age_added  norm_added  norm_target
# MAPE      0.1738    0.1743     0.1738      0.1745       0.1424
# MAE    1664.7240 1675.0652  1676.7070   1677.4705    1654.7988
# RMSE   4951.5050 4941.1828  4987.1651   4946.9444    5369.0246

# %% [markdown]
# Модель стала менее чуствительна к выбросам целевой переменной. В результате, в среднем предсказания модели стали точнее. Вместе с тем, предсказание экстремальных значений стало менее точным (RMSE повысился).

# %%
data.drop(['mileage_norm','eng_pwr_norm', 'age','years_in_prod'],axis=1,inplace=True)
for column in ['mileage_norm','eng_pwr_norm', 'age','years_in_prod']:
    num_cols.remove(column)

# Удаление промежуточных шагов
results.drop(['age_added', 'norm_added','norm_target'], axis=1, inplace=True)

# Расчет и запись метрик
results['post_num'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num
# MAPE      0.1738    0.1743    0.1418
# MAE    1664.7240 1675.0652 1636.6076
# RMSE   4951.5050 4941.1828 5260.0485

# %% [markdown]
# # Feature Engineering

# %%
# Функция возвращает важность переменных для модели
def get_feature_importance(data, target, model=CatBoostRegressor(random_seed = RS, silent=True)):
    df = data.copy()
    
    # Кодирование
    LE = LabelEncoder()
    for col in bin_cols+cat_cols:
        if df[col].dtype == object:
            df[col] = df[col].fillna('Non_specified')
            df[col] = df[col].apply(lambda x: str(x))
            df[col] = LE.fit_transform(df[col])
    
    # Разделение переменных
    cols = df[sorted(bin_cols+cat_cols+num_cols)].drop(['rur_price', 'eur_price', 'usd_price'], axis=1).columns
    X = df[sorted(bin_cols+cat_cols+num_cols)].drop(['rur_price', 'eur_price', 'usd_price'], axis=1).values
    y = df[target].values
    
    # Расчет важности переменных
    model.fit(X, np.log(y))
    FE = pd.Series(model.get_feature_importance(), index=cols).sort_values(ascending=False)
    
    # Визуализация
    plt.figure(figsize=(15,10))
    ax = sns.barplot(x=FE.values, y=FE.index, palette = 'viridis')
    ax.set(ylabel='FEATURE', xlabel='RELATIVE IMPORTANCE (%%)')
    plt.show()
    display(pd.DataFrame(FE, columns=['score']).T)

# %%
get_feature_importance(data[data.train==1], 'eur_price')
# Out:
#        productionDate  modelDate  eng_pwr  eng_volume  mileage  bodyType  \
# score         22.9087    20.2653  17.3142      8.8120   7.3267    4.9329
#
#        brand  model_name  fuelType  Привод  parsing_unixtime  vendor  gen_id  \
# score 4.8786      3.3639    3.0879  1.7396            1.1837  1.0551  0.7106
#
#        numberOfDoors  vehicleTransmission  Владельцы  eqp_amount   Руль  \
# score         0.6233               0.5240     0.3480      0.3112 0.2174
#
#        own_time  color    ПТС  comp_id
# score    0.2063 0.0780 0.0732   0.0395

# %% [markdown]
# Наиболее полезно себя показывают числовые переменные productionDate и modelDate.
#
# В то же время, категориальные признаки brand и model_name показывают себя относительно плохо. Имеет смысл поэксперементировать с расчетом статистик для данных групп.

# %% [markdown]
# ## Stats

# %% [markdown]
# ### Brand

# %% [markdown]
# Для brand расчитаем среднеарифметическое стандартизированых средней и максимальной цен.
# - Это позволит нивелировать ошибку среднего (к примеру, если автопроизводитель представлен более старыми авто, среднее значение будет ниже и не отобразит относительной цены бренда), и ошибку максимума (к примеру, у автопроизводителя имеются модели, выбивающиеся из общего модельного ряда в большую сторону, завышая относительную цену бренда).

# %%
# Расчет статистик по брендам
stat_max = data[data.train==1].groupby('brand').eur_price.max()
stat_avg = data[data.train==1].groupby('brand').eur_price.mean()
stat = pd.DataFrame({'brand':stat_max.index, 'max_price':stat_max.values})
stat['mean_price'] = stat.brand.apply(lambda x: stat_avg[x])
max_price_range = stat.max_price.max() - stat.max_price.min()
mean_price_range = stat.mean_price.max() - stat.mean_price.min()
stat['stat'] = ((stat.max_price-stat.max_price.min())/max_price_range 
                + (stat.mean_price-stat.mean_price.min())/mean_price_range)/2
stat.sort_values(by='stat',inplace = True)
stat.reset_index(drop=True, inplace = True)
stat['ordinal_code'] = stat.index
stat
# Out:
#          brand   max_price  mean_price   stat  ordinal_code
# 0        HONDA  63489.0000   6416.8519 0.0208             0
# 1        SKODA  33107.0000   8454.9471 0.0391             1
# 2       NISSAN  95284.0000   7551.0847 0.0643             2
# 3   MITSUBISHI 105934.0000   8753.7292 0.0947             3
# 4   VOLKSWAGEN  94721.0000  11000.9098 0.1301             4
# 5       TOYOTA 152640.0000  11246.5535 0.1744             5
# 6        VOLVO  85997.0000  15418.9599 0.2088             6
# 7     INFINITI  73099.0000  17176.7699 0.2337             7
# 8         AUDI 166024.0000  14753.6453 0.2508             8
# 9          BMW 181531.0000  25374.9596 0.4651             9
# 10       LEXUS 186467.0000  26244.2934 0.4851            10
# 11    MERCEDES 763343.0000  32496.7598 1.0000            11

# %%
# Визуализация отношения средней и максимальной цен
sns.lmplot(data=stat, x='max_price', y='mean_price', palette = 'viridis')

# %% [markdown]
# Имеет смысл кластеризовать автопроизводителей, фактически обозначив сигменты рынка. Визуально выделяются 5.

# %%
# Предсказание кластера
kmeans = KMeans(n_clusters=5)
kmeans.fit(MinMaxScaler().fit_transform(stat[['max_price', 'mean_price']]))
stat['brand_cluster'] = kmeans.labels_.astype(np.int)

# %%
# Визуализация
sns.relplot(data=stat, x='max_price', y='mean_price', hue='brand_cluster', palette = 'viridis')

# %% [markdown]
# Поскольку KMeans назначает имена случайным образом, имеет смысл упорядочить их согласно значению статистики.

# %%
# Изменение значения кластера на ординальное
ord_clust = stat.groupby('brand_cluster').stat.mean().sort_values()
mapping_dict = {}
for i in range(ord_clust.shape[0]):
    mapping_dict[ord_clust.index[i]] = i
stat['brand_cluster'] = stat.brand_cluster.map(mapping_dict)

# %% [markdown]
# Тестирование:

# %%
# Добавление параметра
mapping_dict = {}
for i in range(stat.shape[0]):
    mapping_dict[stat.brand.loc[i]] = i
data['ord_brand'] = data.brand.map(mapping_dict)
cat_cols.append('ord_brand')

# Расчет и запись метрик
results['ob_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  ob_added
# MAPE      0.1738    0.1743    0.1418    0.1414
# MAE    1664.7240 1675.0652 1636.6076 1625.2435
# RMSE   4951.5050 4941.1828 5260.0485 5259.8889

# %% [markdown]
# Добавление упорядоченного кодирования бренда дало небольшое улучшение работы модели.

# %%
# Добавление параметра
mapping_dict = {}
for i in range(stat.shape[0]):
    mapping_dict[stat.brand.loc[i]] = stat.brand_cluster.loc[i]
data['brand_cluster'] = data.brand.map(mapping_dict)
cat_cols.append('brand_cluster')

# Расчет и запись метрик
results['bc_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  ob_added  bc_added
# MAPE      0.1738    0.1743    0.1418    0.1414    0.1415
# MAE    1664.7240 1675.0652 1636.6076 1625.2435 1630.6258
# RMSE   4951.5050 4941.1828 5260.0485 5259.8889 5222.5177

# %% [markdown]
# Кластер бренда не несет ценности для модели.

# %%
# Удаление brand_cluster
cat_cols.remove('brand_cluster')
data.drop('brand_cluster', axis=1, inplace=True)

# %% [markdown]
# ### Model

# %% [markdown]
# Модели авто будут рассмотрены по каждому бренду. Для каждой моделей рассчитаем статистику, аналогичную той, что считались ранее (Если модель присутствует только в тесте, берется среднеарифметическое по бренду). Далее, упорядочиваем модели по статистике внутри бренда и стандартизируем позицию. Таким образом, мы получаем относительное положение модели внутри линейки бренда (самые дорогие авто = 1, самые дешевые = 0).

# %%
# Функция возвращает значение, если оно имеется
# В противном случае 'None'
def get_price(df, model):
    try:
        return df[model]
    except:
        return None

# %%
# Расчет относительного рейтинга модели
mapping_dict = {}
for mark in tqdm(data.brand.unique()):
    stat = pd.DataFrame({'model':data[data.brand==mark].model_name.unique()})
    stat_max = data[(data.train==1)&(data.brand==mark)].groupby('model_name').eur_price.max()
    stat['max_price'] = stat.model.apply(lambda x: get_price(stat_max, x))
    stat_mean = data[(data.train==1)&(data.brand==mark)].groupby('model_name').eur_price.mean()
    stat['mean_price'] = stat.model.apply(lambda x: get_price(stat_mean, x))
    max_price_range = stat.max_price.max() - stat.max_price.min()
    mean_price_range = stat.mean_price.max() - stat.mean_price.min()
    stat['stat'] = ((stat.max_price-stat.max_price.min())/max_price_range 
                    + (stat.mean_price-stat.mean_price.min())/mean_price_range)/2
    stat['stat'] = stat.stat.fillna(stat.stat.mean())
    stat.sort_values(by='stat',inplace = True)
    stat.reset_index(drop=True, inplace = True)
    stat['ordinal_code'] = stat.index
    stat.stat.fillna(stat.stat.mean())
    for i in stat.index:
        mapping_dict[stat.loc[i]['model']] = stat.loc[i]['ordinal_code']/stat['ordinal_code'].max()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=12.0), HTML(value='')))

# %%
data['rel_model'] = data.model_name.map(mapping_dict)
num_cols.append('rel_model')

# Расчет и запись метрик
results['rm_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  ob_added  bc_added  rm_added
# MAPE      0.1738    0.1743    0.1418    0.1414    0.1415    0.1383
# MAE    1664.7240 1675.0652 1636.6076 1625.2435 1630.6258 1561.0964
# RMSE   4951.5050 4941.1828 5260.0485 5259.8889 5222.5177 5102.4822

# %% [markdown]
# Параметр относительного рейтинга модели улучшает работу модели. Судя по более резкому снижению MAPE и RMSE относительно MAPE, улучшения больше сказываются на предсказании более дорогих и редких авто.

# %% [markdown]
# ### Decades

# %% [markdown]
# Так как зависимость возраста авто и его цены нелинейна (наиболее старые и новые авто дороже), имеет смысл поэксперементировать с разделением времени на отрезки. Несмотря на то,что в градиентный бустинг встроен подобный алгоритм, эксперимент может быть полезен.

# %%
sns.lmplot(data=data[data.train==1], x='productionDate', y='eur_price', palette = 'viridis')

# %%
data['decade'] = data.productionDate.apply(lambda x: (int(x/10))*10)

# %%
stat = pd.DataFrame({'decade':data.decade.unique()})
stat_max = data[data.train==1].groupby('decade').eur_price.max()
stat['max_price'] = stat.decade.apply(lambda x: get_price(stat_max, x))
stat_avg = data[data.train==1].groupby('decade').eur_price.mean()
stat['mean_price'] = stat.decade.apply(lambda x: get_price(stat_avg, x))
stat.sort_values(by='decade',inplace = True)
stat.fillna(method='backfill', inplace = True)
max_price_range = stat.max_price.max() - stat.max_price.min()
mean_price_range = stat.mean_price.max() - stat.mean_price.min()
stat['stat'] = ((stat.max_price-stat.max_price.min())/max_price_range 
                + (stat.mean_price-stat.mean_price.min())/mean_price_range)/2
stat.sort_values(by='stat',inplace = True)
stat.reset_index(drop=True, inplace = True)
stat['ordinal_code'] = stat.index
stat
# Out:
#     decade   max_price  mean_price   stat  ordinal_code
# 0     1980  44157.0000   2127.7339 0.0000             0
# 1     1970 101496.0000   8819.6466 0.0653             1
# 2     1940  66862.0000  26510.1818 0.1084             2
# 3     2000 349413.0000   6177.9203 0.2276             3
# 4     1930 390029.0000  41649.3125 0.3906             4
# 5     1960 216236.0000  80594.0455 0.4178             5
# 6     2010 658454.0000  19881.2615 0.4945             6
# 7     1990 763343.0000   2984.0288 0.5033             7
# 8     1900 133724.0000 133724.0000 0.5623             8
# 9     2020 729196.0000  43123.6234 0.6320             9
# 10    1950 585044.0000 126874.5769 0.8500            10

# %%
# Добавление параметра
mapping_dict = {}
for i in range(stat.shape[0]):
    mapping_dict[stat.decade.loc[i]] = i
data['decade'] = data.decade.map(mapping_dict)
cat_cols.append('decade')

# Расчет и запись метрик
results['dec_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  ob_added  bc_added  rm_added  dec_added
# MAPE      0.1738    0.1743    0.1418    0.1414    0.1415    0.1383     0.1381
# MAE    1664.7240 1675.0652 1636.6076 1625.2435 1630.6258 1561.0964  1559.6489
# RMSE   4951.5050 4941.1828 5260.0485 5259.8889 5222.5177 5102.4822  5130.0938

# %% [markdown]
# Параметр decade снижает целевую метрику.

# %% [markdown]
# ### Body type

# %%
data.bodyType.value_counts()
# Out:
# внедорожник 5 дв.          57521
# седан                      54871
# хэтчбек 5 дв.              11737
# лифтбек                     7312
# универсал 5 дв.             6212
#                            ...
# универсал 5 дв. gracia         1
# универсал 3 дв.                1
# универсал 5 дв. shuttle        1
# седан gracia                   1
# седан latio                    1
# Name: bodyType, Length: 102, dtype: int64

# %%
# Сократим количество типов кузова до основных
data['body'] = data['bodyType'].apply(lambda x: x[:4])
cat_cols.append('body')

data['body'].value_counts()
# Out:
# внед    58207
# седа    56456
# хэтч    13821
# лифт     7604
# унив     6263
# мини     5674
# комп     4012
# купе     3896
# пика     1662
# фург      694
# родс      384
# кабр      300
# микр       43
# лиму       16
# тарг        7
# фаст        4
# Name: body, dtype: int64

# %%
# Расчет и запись метрик
results['body_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  ob_added  bc_added  rm_added  dec_added  \
# MAPE      0.1738    0.1743    0.1418    0.1414    0.1415    0.1383     0.1381
# MAE    1664.7240 1675.0652 1636.6076 1625.2435 1630.6258 1561.0964  1559.6489
# RMSE   4951.5050 4941.1828 5260.0485 5259.8889 5222.5177 5102.4822  5130.0938
#
#       body_added
# MAPE      0.1383
# MAE    1557.9206
# RMSE   5050.2973

# %% [markdown]
# По некоторым признакам есть небольшая разница при расчете метрики на каггл и на домашних машинах (в четвертом знаке). Видимо, это связано с версиями пакетов. Выводы о полезности признака мы делали, исходя из результатов, полученных на домашних машинах. Поэтому они могут противоречить тому, что получилось на каггл. В конце все равно все лишнее уберем.
# Признак body пока оставим.

# %% [markdown]
# ### Color

# %%
# Определим популярные цвета и добавим признак "популярный цвет"
data['color'].value_counts()
# Out:
# чёрный         46475
# белый          31789
# серый          20088
# серебристый    18819
# синий          14822
# красный         6952
# коричневый      6305
# зелёный         4617
# бежевый         2599
# голубой         2000
# золотистый      1211
# пурпурный       1056
# фиолетовый       905
# жёлтый           688
# оранжевый        614
# розовый          103
# Name: color, dtype: int64

# %%
popular_color = ['чёрный', 'белый', 'серый', 'серебристый']
data['pop_color'] = data['color'].apply(lambda x: 1 if x in popular_color else 0)
cat_cols.append('pop_color')

# %%
# Расчет и запись метрик
results['color_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  ob_added  bc_added  rm_added  dec_added  \
# MAPE      0.1738    0.1743    0.1418    0.1414    0.1415    0.1383     0.1381
# MAE    1664.7240 1675.0652 1636.6076 1625.2435 1630.6258 1561.0964  1559.6489
# RMSE   4951.5050 4941.1828 5260.0485 5259.8889 5222.5177 5102.4822  5130.0938
#
#       body_added  color_added
# MAPE      0.1383       0.1380
# MAE    1557.9206    1557.3587
# RMSE   5050.2973    5057.7758

# %%
# Популярный цвет ухудшил метрику, удалим признак
cat_cols.remove('pop_color')
data.drop('pop_color', axis=1, inplace=True)

# %% [markdown]
# ### Premium brands

# %%
# Посмотрим, у каких брендов, в среднем, более высокая цена
brand_data = data[data['train'] == 1].groupby(['brand'])['eur_price'].mean().sort_values(ascending=False)
brand_data
# Out:
# brand
# MERCEDES     32496.7598
# LEXUS        26244.2934
# BMW          25374.9596
# INFINITI     17176.7699
# VOLVO        15418.9599
# AUDI         14753.6453
# TOYOTA       11246.5535
# VOLKSWAGEN   11000.9098
# MITSUBISHI    8753.7292
# SKODA         8454.9471
# NISSAN        7551.0847
# HONDA         6416.8519
# Name: eur_price, dtype: float64

# %%
# Также посмотрим максимальные цены по брендам
brand_data_max = data[data['train'] == 1].groupby(['brand'])['eur_price'].max().sort_values(ascending=False)
brand_data_max
# Out:
# brand
# MERCEDES     763343.0000
# LEXUS        186467.0000
# BMW          181531.0000
# AUDI         166024.0000
# TOYOTA       152640.0000
# MITSUBISHI   105934.0000
# NISSAN        95284.0000
# VOLKSWAGEN    94721.0000
# VOLVO         85997.0000
# INFINITI      73099.0000
# HONDA         63489.0000
# SKODA         33107.0000
# Name: eur_price, dtype: float64

# %%
# Можно выделить трех лидеров
# Введем признак "премиальный бренд", который может сильно влиять на цену

data['premium'] = data['brand'].apply(lambda x: 1 if x in ['MERCEDES','LEXUS','BMW'] else 0)
cat_cols.append('premium')

# %%
# Расчет и запись метрик
results['pre_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  ob_added  bc_added  rm_added  dec_added  \
# MAPE      0.1738    0.1743    0.1418    0.1414    0.1415    0.1383     0.1381
# MAE    1664.7240 1675.0652 1636.6076 1625.2435 1630.6258 1561.0964  1559.6489
# RMSE   4951.5050 4941.1828 5260.0485 5259.8889 5222.5177 5102.4822  5130.0938
#
#       body_added  color_added  pre_added
# MAPE      0.1383       0.1380     0.1384
# MAE    1557.9206    1557.3587  1568.4450
# RMSE   5050.2973    5057.7758  5257.2457

# %%
# Признак ухудшил метрику, удалим признак
cat_cols.remove('premium')
data.drop('premium', axis=1, inplace=True)

# %% [markdown]
# ### Итог:

# %%
# Удаление промежуточных шагов
results.drop(['ob_added', 'bc_added','rm_added','dec_added','body_added','color_added','pre_added'], axis=1, inplace=True)

# Расчет и запись метрик
results['post_stat'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  post_stat
# MAPE      0.1738    0.1743    0.1418     0.1383
# MAE    1664.7240 1675.0652 1636.6076  1557.9206
# RMSE   4951.5050 4941.1828 5260.0485  5050.2973

# %%
get_feature_importance(data[data.train==1], 'eur_price')
# Out:
#        productionDate  modelDate  eng_pwr  eng_volume  ord_brand  rel_model  \
# score         26.3710    14.7583  14.0835      7.9016     7.8987     7.0690
#
#        mileage   body  bodyType  decade  fuelType  model_name  Привод  brand  \
# score   6.1808 2.2983    2.1677  1.9947    1.9807      1.5495  0.8935 0.8633
#
#        vendor  parsing_unixtime  numberOfDoors  gen_id  eqp_amount  Владельцы  \
# score  0.6361            0.6262         0.6011  0.4813      0.3982     0.3187
#
#        vehicleTransmission   Руль  own_time  color    ПТС  comp_id
# score               0.2884 0.2375    0.2116 0.0955 0.0751   0.0198

# %% [markdown]
# В ходе расчета статистик, удалось добавить параметры, которые улучшили работу модели.

# %% [markdown]
# ## PCA

# %%
# Удаление параметров: цены, modelDate, высокосколериванный с productionDate, и времени парсинга
train = data[data.train==1].reset_index()
PCA_features = train[num_cols].drop(['rur_price', 'usd_price', 'parsing_unixtime', 
                                     'productionDate', 'rur_price'], axis=1)

# Стандартизация числовых переменных, выделение целевой
A = MinMaxScaler().fit_transform(PCA_features.drop('eur_price', axis=1).values)
b = PCA_features.eur_price

# %%
# Применение метода главных компонент
pca = PCA(random_state = RS)
A_pca = pca.fit_transform(A)
component_names = [f"PC{i+1}" for i in range(A_pca.shape[1])]

A_pca = pd.DataFrame(A_pca, columns=component_names)
A_pca.head()
# Out:
#       PC1     PC2     PC3     PC4     PC5     PC6     PC7
# 0 -0.1431 -0.1059  0.0081 -0.0624  0.0824 -0.0112 -0.0018
# 1 -0.1332 -0.1032  0.0533 -0.0915 -0.0248 -0.0557  0.0004
# 2 -0.1470 -0.1015 -0.0081 -0.0288 -0.0042 -0.0053 -0.0014
# 3 -0.1184 -0.0531  0.0987 -0.0060 -0.0211  0.0612 -0.0016
# 4 -0.1390 -0.1039  0.0227 -0.0700 -0.0191 -0.0087 -0.0014

# %%
# Расчет важности компонент
M = CatBoostRegressor(random_seed = RS, silent=True)
M.fit(A_pca, np.log(b))
FI = pd.Series(M.get_feature_importance(), index=component_names).sort_values(ascending=False)
    
# Визуализация
plt.figure(figsize=(15,10))
ax = sns.barplot(x=FI.values, y=FI.index, palette = 'viridis')
ax.set(ylabel='FEATURE', xlabel='RELATIVE IMPORTANCE (%%)')
plt.show()
display(pd.DataFrame(FI, columns=['score']).T)
# Out:
#           PC3     PC1     PC2     PC6    PC7    PC4    PC5
# score 34.1845 30.6746 13.4246 11.8185 4.5713 4.5007 0.8258

# %%
# Датафрейм для анализа результатов
for_analysis = pd.DataFrame(A, columns=PCA_features.drop('eur_price', axis=1).columns)
for_analysis['target'] = b

# %% [markdown]
# ### Наиболее полезная компонента

# %%
# Голова и хвост выборки, упорядоченной по наиболее полезной компоненте
idx = A_pca[FI.index[0]].sort_values(ascending=False).index

display(for_analysis.loc[idx].head(10))
display(for_analysis.loc[idx].tail(10))
# Out:
#         mileage  modelDate  numberOfDoors  eng_volume  eng_pwr  own_time  \
# 8127     1.0000     0.2759         0.8000      0.0057   0.0104    0.0000
# 39779    1.0000     0.6983         1.0000      0.0080   0.0948    0.0000
# 110637   1.0000     0.7328         1.0000      0.0140   0.1753    0.0813
# 109600   0.9900     0.7500         1.0000      0.0043   0.0753    0.0606
# 39785    1.0000     0.6983         1.0000      0.0100   0.1623    0.1107
# 14327    1.0000     0.8276         1.0000      0.0053   0.0935    0.0000
# 39742    1.0000     0.7931         1.0000      0.0090   0.1234    0.0000
# 114762   1.0000     0.6810         1.0000      0.0053   0.0519    0.0000
# 13331    1.0000     0.7069         0.8000      0.0083   0.0714    0.0000
# 57192    1.0000     0.7931         1.0000      0.0113   0.1922    0.0000
#
#         rel_model    target
# 8127       0.8507 3328.0000
# 39779      0.7468 4968.0000
# 110637     0.9764 6129.0000
# 109600     0.6929  669.0000
# 39785      0.7468 2594.0000
# 14327      0.7143 2539.0000
# 39742      0.7468 2318.0000
# 114762     0.2432  780.0000
# 13331      0.7660 6101.0000
# 57192      0.9213 5792.0000
#         mileage  modelDate  numberOfDoors  eng_volume  eng_pwr  own_time  \
# 107483   0.0000     0.9741         0.4000      0.0133   0.7558    0.0000
# 107436   0.0000     0.9741         0.4000      0.0133   0.7558    0.0000
# 107438   0.0000     0.9741         0.4000      0.0133   0.7558    0.0000
# 107493   0.0000     0.9741         0.4000      0.0133   0.7558    0.0000
# 107465   0.0000     0.9741         0.4000      0.0133   0.7558    0.0000
# 107497   0.0000     0.9741         0.4000      0.0133   0.7558    0.0000
# 107476   0.0000     0.9741         0.4000      0.0133   0.7558    0.0000
# 107551   0.0046     0.9655         0.4000      0.0183   0.7208    0.0000
# 8052     0.0140     0.9138         0.4000      0.0183   0.7026    0.0000
# 8059     0.0417     0.8793         0.4000      0.0200   0.7558    0.0000
#
#         rel_model      target
# 107483     0.7612 184961.0000
# 107436     0.7612 206515.0000
# 107438     0.7612 162502.0000
# 107493     0.7612 205244.0000
# 107465     0.7612 184196.0000
# 107497     0.7612 166792.0000
# 107476     0.7612 176814.0000
# 107551     0.5970  88035.0000
# 8052       0.3134  46588.0000
# 8059       0.3134  33277.0000

# %% [markdown]
# Судя по выборке, компонента основана на numberOfDoors и mileage.

# %%
sns.lmplot(data=data[data.train==1], x='numberOfDoors', y='mileage', palette = 'viridis')

# %% [markdown]
# Можно предположить, что кол-во дверей коррелирует с размером авто. Судя по тому, что пробег с ростом кол-ва дверей снижется, возможно срок службы для больших авто ниже.
#
# Создадим переменную rel_mileage, с отношением пройденых км к кол-ву дверей.

# %%
data['rel_mileage'] = data['mileage']/(data['numberOfDoors']+1)
num_cols.append('rel_mileage')

# Рассчет и запись метрик
results['rm_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  post_stat  rm_added
# MAPE      0.1738    0.1743    0.1418     0.1383    0.1387
# MAE    1664.7240 1675.0652 1636.6076  1557.9206 1563.7097
# RMSE   4951.5050 4941.1828 5260.0485  5050.2973 5072.5223

# %% [markdown]
# Признак снижает целевую метрику и может быть удален.
#
# В целом, так как не удолось синтезировать полезный признак на основе наиболее полезной компоненты, не имеет смысла анализировать дальнейшие.

# %%
# Удаление rel_mileage
num_cols.remove('rel_mileage')
data.drop('rel_mileage', axis=1, inplace=True)

# Удаление промежуточных шагов
results.drop(['rm_added'], axis=1, inplace=True)

# %% [markdown]
# ## Текст

# %% [markdown]
# ### Equipment

# %% [markdown]
# Для наиболее популярных опций (встречаются более 50 раз), попытаемся рассчитать вклад в цену авто. Для этого будут использованы коэффициенты линейной регрессии.

# %%
# Создание вспомогательного dataframe для обработки
for_processing = data[(data.train==1)&(data.eqp_amount>0)].dropna(axis = 0, subset = ['eqp_options']).copy()
for_processing = for_processing[['sell_id','eqp_options','eur_price']].drop_duplicates(subset='sell_id')
display(for_processing.shape)
for_processing.sample(3)
# Out:
# (48609, 3)
#               sell_id                                        eqp_options  \
# 48784 1103037549.0000  [electro-window-back, asr, start-button, leath...
# 43219 1103172299.0000                                   [condition, abs]
# 36985 1102397984.0000  [cruise-control, tinted-glass, esp, usb, multi...
#
#        eur_price
# 48784 17225.0000
# 43219  2208.0000
# 36985  5520.0000

# %%
# Уникальные значения, встречающиеся более 50 раз
all_options = []
for i in tqdm(for_processing.index):
    all_options += for_processing.loc[i]['eqp_options']
all_options = pd.Series(all_options).value_counts()
all_options = list(all_options[all_options>50].index)
print('Unique options: ',len(all_options))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=48609.0), HTML(value='')))
# Unique options:  176

# %%
# Функция проверяет наличие опции в списке
def get_eqp_dummy(option, eqp_list):
    if option in eqp_list:
        return 1
    else:
        return 0

# %%
# Dummy-кодирование
for option in tqdm(all_options):
    for_processing[option] = for_processing.eqp_options.apply(lambda x: get_eqp_dummy(option, x))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=176.0), HTML(value='')))

# %%
for_processing.sample(3)
# Out:
#               sell_id                                        eqp_options  \
# 1126  1103206235.0000  [usb, wheel-power, hatch, lock, automatic-ligh...
# 66984 1102765810.0000  [cruise-control, computer, abs, esp, seat-tran...
# 32074 1103258865.0000                  [aux, wheel-power, panorama-roof]
#
#        eur_price  abs  lock  electro-mirrors  computer  front-seats-heat  \
# 1126    774.0000    0     1                0         0                 0
# 66984  9478.0000    1     1                1         1                 0
# 32074  9383.0000    0     0                0         0                 0
#
#        immo  airbag-driver  electro-window-front  ptf  airbag-passenger  aux  \
# 1126      0              0                     0    0                 0    0
# 66984     1              0                     0    0                 0    0
# 32074     0              0                     0    0                 0    1
#
#        esp  usb  ...  laser-lights  night-vision  seats-8  adj-pedals  \
# 1126     0    1  ...             0             0        0           0
# 66984    1    0  ...             0             0        0           0
# 32074    0    0  ...             0             0        0           0
#
#        22-inch-wheels  laminated-safety-glass  duo-body-color  ya-auto  \
# 1126                0                       0               0        0
# 66984               0                       0               0        0
# 32074               0                       0               0        0
#
#        seats-6  armored  13-inch-wheels  airbrush  front-camera  seats-2  \
# 1126         0        0               0         0             0        0
# 66984        0        0               0         0             0        0
# 32074        0        0               0         0             0        0
#
#        electro-window-all  seats-heat
# 1126                    0           0
# 66984                   0           0
# 32074                   0           0
#
# [3 rows x 179 columns]

# %%
# Обучение линейной регрессии
X = for_processing[for_processing.columns[3:]]
y = for_processing['eur_price']
LR = LinearRegression()
LR.fit(X,y)
# Out:
# LinearRegression()

# %%
# Словарь с парами опция-коэффициент
options_coef = {}
for i in range(len(all_options)):
    options_coef[X.columns[i]] = LR.coef_[i]

# %%
# Функция возвращает сумму коэфициентов для списка eqp_options
def get_eqp_rating(row):
    if row.eqp_amount > 0:
        rating = 0
        for option in row.eqp_options:
            try:
                rating += options_coef[option]
            except:
                rating += 0
        return rating
    else:
        return None

# %% [markdown]
# #### Заполнение:

# %%
# Применение функции
data['eqp_amount'] = data.eqp_amount.fillna(0)
data['eqp_rating'] = data.progress_apply(get_eqp_rating, axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=159043.0), HTML(value='')))

# %%
# Стандартизация и визуализация признака
data['eqp_rating'] = StandardScaler().fit_transform(data.eqp_rating.values.reshape(-1, 1))
sum_up_num(data, 'eqp_rating', 'eur_price')
# Out:
# EQP_RATING
# mean    0.0024
# std     1.0044
# min    -2.3004
# 25%    -0.6107
# 50%    -0.3138
# 75%     0.3494
# max     7.6636
# Name: eqp_rating, dtype: float64
# Кол-во выбросов: 3102 	 (%%: 2.49)

# %%
num_cols.append('eqp_rating')

# Расчет и запись метрик
results['er_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  post_stat  er_added
# MAPE      0.1738    0.1743    0.1418     0.1383    0.1383
# MAE    1664.7240 1675.0652 1636.6076  1557.9206 1562.0415
# RMSE   4951.5050 4941.1828 5260.0485  5050.2973 5073.1159

# %% [markdown]
# Добавление eqp_rating немного улучшает модель c точки зрения предсказания выбросов (RSME снизился).

# %% [markdown]
# ### Description

# %%
# Токинизатор
CVec = CountVectorizer(stop_words=stopwords.words('russian')).build_analyzer()

# %%
# Создание вспомогательного dataframe, токенизация текста
for_processing = data.dropna(axis = 0, subset = ['description']).copy()
for_processing = for_processing[['sell_id','description']].drop_duplicates(subset='sell_id')
for_processing['wordbox'] = for_processing.description.progress_apply(lambda x: CVec(x))
for_processing.sample(3)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=109804.0), HTML(value='')))
#               sell_id                                        description  \
# 51212 1102380976.0000  Мерседес GLK Отличный, надежный и очень комфор...
# 68633 1103335133.0000  Ваш выбор и Ваше время — наши главные приорите...
# 25337 1103308134.0000  Продаю Honda Civic 8, авто в отличном состояни...
#
#                                                  wordbox
# 51212  [мерседес, glk, отличный, надежный, очень, ком...
# 68633  [ваш, выбор, ваше, время, наши, главные, приор...
# 25337  [продаю, honda, civic, авто, отличном, состоян...

# %%
# Модель преобразования слов в вектора
dimensions = 10
word_model = Word2Vec(for_processing.wordbox, min_count=50, size=dimensions)

# %%
# Функция возвращает усредненный вектор документа на основе векторов слов
def doc_vectorizer(doc, model=word_model):
    doc_vector = []
    num_words = 0
    for word in doc:
        try:
            if num_words == 0:
                doc_vector = model[word]
            else:
                doc_vector = np.add(doc_vector, model[word])
            num_words += 1
        except:
            pass
     
    return np.asarray(doc_vector) / num_words

# %%
# Применение функции
for_processing['box_vec'] = for_processing.wordbox.progress_apply(doc_vectorizer)
for_processing['vec_dems'] = for_processing.box_vec.apply(lambda x: len(x))
for_processing = for_processing[for_processing.vec_dems>0].drop('vec_dems',axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=109804.0), HTML(value='')))
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Добавление векторов в dataframe
for i in tqdm(range(1,dimensions+1)):
    for_processing['vec_{}'.format(i)] = for_processing.box_vec.apply(lambda x: x[i-1])
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
for_processing.sample(3)
# Out:
#               sell_id                                        description  \
# 85927 1101274203.0000  Машина на ходу, используется редко, повреждени...
# 63971 1093987664.0000  порван левый привод 3 месяца назад.и с тех пор...
# 99245 1101018306.0000  Машина действительно в отличном состоянии без ...
#
#                                                  wordbox  \
# 85927  [машина, ходу, используется, редко, повреждени...
# 63971  [порван, левый, привод, месяца, назад, тех, по...
# 99245  [машина, действительно, отличном, состоянии, д...
#
#                                                  box_vec  vec_1   vec_2  \
# 85927  [3.7592487, -0.18892741, 0.1815689, -1.3416783... 3.7592 -0.1889
# 63971  [1.3857032, -0.015365571, -0.2939103, 0.804848... 1.3857 -0.0154
# 99245  [2.9946725, -0.308688, 1.1599435, 0.40347043, ... 2.9947 -0.3087
#
#         vec_3   vec_4  vec_5   vec_6  vec_7   vec_8   vec_9  vec_10
# 85927  0.1816 -1.3417 4.2963 -1.2196 1.8778 -2.6662 -0.3689 -1.8725
# 63971 -0.2939  0.8048 4.8352  0.7271 1.9517  2.1799 -0.3138 -0.7097
# 99245  1.1599  0.4035 3.6212 -1.5372 2.9710  0.6916 -0.0786 -0.1677

# %%
# Функция возвращает коэффициент силуэта для кол-ва кластеров
def k_means(nc):
    kmeans = KMeans(n_clusters=nc, random_state=RS)
    X = for_processing[for_processing.columns[4:]]
    kmeans.fit(X)
    pred = kmeans.labels_.astype(np.int)+1
    return silhouette_score(X, pred, metric='euclidean')

# %%
# Применение функции
kmeans_scores = pd.DataFrame({'n_clusters':[5,10,20]})
kmeans_scores['score'] = kmeans_scores.n_clusters.progress_apply(k_means)
kmeans_scores
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3.0), HTML(value='')))
#    n_clusters  score
# 0           5 0.2332
# 1          10 0.2171
# 2          20 0.1628

# %% [markdown]
# Кэффициент силуэта невысокий и снижается с увеличением кол-ва кластеров. Для предсказания будем использовать 5 кластеров.

# %%
# Предсказание кластера
kmeans = KMeans(n_clusters=5, random_state=RS)
kmeans.fit(for_processing[for_processing.columns[4:]])
for_processing['desc_cluster'] = kmeans.labels_.astype(np.int)+1

# %%
for_processing.sample(3)
# Out:
#               sell_id                                        description  \
# 30153 1103276234.0000  Вашему вниманию представляется автомобиль BMW ...
# 2799  1102675936.0000           Прошу перекупы, Автосалон не беспокоить.
# 66481 1103145557.0000  Продажа от Официального дилера Компании АВТОРУ...
#
#                                                  wordbox  \
# 30153  [вашему, вниманию, представляется, автомобиль,...
# 2799            [прошу, перекупы, автосалон, беспокоить]
# 66481  [продажа, официального, дилера, компании, авто...
#
#                                                  box_vec  vec_1   vec_2  \
# 30153  [1.4983277, -1.445469, 3.099391, -3.211143, -3... 1.4983 -1.4455
# 2799   [0.6550882, -2.626382, -4.6285644, -6.133204, ... 0.6551 -2.6264
# 66481  [0.12517665, 0.56384045, 2.0460105, 0.18337458... 0.1252  0.5638
#
#         vec_3   vec_4   vec_5   vec_6   vec_7   vec_8   vec_9  vec_10  \
# 30153  3.0994 -3.2111 -3.5380 -2.0703 -3.1554  1.9193 -0.7065 -1.5037
# 2799  -4.6286 -6.1332  3.4810 -0.4258 -1.3668 -5.0676 -3.5929 -1.9143
# 66481  2.0460  0.1834 -0.7972  1.4156 -1.4130  1.4042  2.0354 -0.1741
#
#        desc_cluster
# 30153             2
# 2799              4
# 66481             3

# %%
# Словарь для быстрого заполненя.
mapping_dict = {}
for i in tqdm(for_processing.index):
    row = for_processing.loc[i]
    mapping_dict[row['sell_id']] = row['desc_cluster']
# Out:
# HBox(children=(FloatProgress(value=0.0, max=109665.0), HTML(value='')))

# %%
# Функция возвращает кластер по ID
def get_desc_cluster(sl_id):
    try:
        return mapping_dict[sl_id]
    except:
        return 0

# %%
# Применение функции
data['desc_cluster'] = data.sell_id.apply(get_desc_cluster)

# %%
cat_cols.append('desc_cluster')

# Расчет и запись метрик
results['dc_added'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  post_stat  er_added  dc_added
# MAPE      0.1738    0.1743    0.1418     0.1383    0.1383    0.1381
# MAE    1664.7240 1675.0652 1636.6076  1557.9206 1562.0415 1561.6907
# RMSE   4951.5050 4941.1828 5260.0485  5050.2973 5073.1159 5109.3961

# %% [markdown]
# Кластеризация текста немного снизила метрики.

# %% [markdown]
# ### Итог:

# %%
# Удаление промежуточных шагов
results.drop(['er_added','dc_added'], axis=1, inplace=True)

# Расчет и запись метрик
results['post_txt'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  post_stat  post_txt
# MAPE      0.1738    0.1743    0.1418     0.1383    0.1381
# MAE    1664.7240 1675.0652 1636.6076  1557.9206 1561.6907
# RMSE   4951.5050 4941.1828 5260.0485  5050.2973 5109.3961

# %%
get_feature_importance(data[data.train==1], 'eur_price')
# Out:
#        productionDate  modelDate  eng_pwr  ord_brand  eng_volume  rel_model  \
# score         25.4441    18.6886  12.6772     7.2234      7.1471     6.6269
#
#        mileage  decade  bodyType  fuelType  model_name  Привод  brand   body  \
# score   5.4721  3.7589    2.9474    1.7028      1.5279  1.0515 0.9003 0.8326
#
#        numberOfDoors  parsing_unixtime  vendor  gen_id  vehicleTransmission  \
# score         0.6003            0.5842  0.5364  0.4595               0.2991
#
#        Владельцы  eqp_rating   Руль  eqp_amount  own_time  desc_cluster  \
# score     0.2810      0.2558 0.2433      0.2394    0.1707        0.1550
#
#        color    ПТС  comp_id
# score 0.0859 0.0693   0.0192

# %% [markdown]
# В ходе обработки текста целевая метрика немного снизилась.

# %% [markdown]
# ## Cleaning

# %% [markdown]
# ### Числовые переменные

# %%
# Создание списка числовых переменных без целевых
cols_to_test = []
for col in num_cols:
    if col in ['rur_price','eur_price','usd_price']:
        continue
    else:
        cols_to_test.append(col)

# %%
# Тестирование и вывод параметров, после удаления которых MAPE снижается
cols_to_drop = []
last_mape = results.loc['MAPE'][results.columns[-1]]

for col in tqdm(cols_to_test):
    num_cols.remove(col)
    new_mape = metics(data[data.train==1], 'eur_price')[0]
    if new_mape < last_mape:
        last_mape = new_mape
        cols_to_drop.append(col)
    else:
        num_cols.append(col)

print('Список для удаления:', cols_to_drop)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# Список для удаления: ['parsing_unixtime', 'own_time']

# %% [markdown]
# ### Категориальные переменные

# %%
# Копирование списка переменных
cols_to_test = []
for col in cat_cols:
    cols_to_test.append(col)
        
# Тестирование и вывод параметров, после удаления которых MAPE снижается
for col in tqdm(cols_to_test):
    cat_cols.remove(col)
    new_mape = metics(data[data.train==1], 'eur_price')[0]
    if new_mape < last_mape:
        last_mape = new_mape
        cols_to_drop.append(col)
    else:
        cat_cols.append(col)

print('Список для удаления:', cols_to_drop)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=16.0), HTML(value='')))
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# Список для удаления: ['parsing_unixtime', 'own_time', 'color', 'decade']

# %% [markdown]
# ### Бинарные переменные

# %%
# Копирование списка переменных
cols_to_test = []
for col in bin_cols:
    cols_to_test.append(col)
        
# Тестирование и вывод параметров, после удаления которых MAPE снижается
for col in tqdm(cols_to_test):
    bin_cols.remove(col)
    new_mape = metics(data[data.train==1], 'eur_price')[0]
    if new_mape < last_mape:
        last_mape = new_mape
        cols_to_drop.append(col)
    else:
        bin_cols.append(col)

print('Список для удаления:', cols_to_drop)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
# Список для удаления: ['parsing_unixtime', 'own_time', 'color', 'decade']

# %% [markdown]
# ### Итог:

# %%
# Расчет и запись метрик
results['post_cleaning'] = metics(data[data.train==1], 'eur_price')

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  post_stat  post_txt  post_cleaning
# MAPE      0.1738    0.1743    0.1418     0.1383    0.1381         0.1375
# MAE    1664.7240 1675.0652 1636.6076  1557.9206 1561.6907      1554.0244
# RMSE   4951.5050 4941.1828 5260.0485  5050.2973 5109.3961      5168.8458

# %%
# Удаление данных (время парсинга необходимо для постобработки)
if 'parsing_unixtime' in cols_to_drop:
    cols_to_drop.remove('parsing_unixtime')
data.drop(cols_to_drop, axis=1, inplace=True)

# %% [markdown]
# # Model Tuning & Prediction

# %% [markdown]
# ## Встроенный подбор параметров CatBoost

# %%
# Функция возвращает метрики для данных и модели
def metics(data, target, model=CatBoostRegressor(random_seed = RS, silent=True)):
    df = data.copy()
    
    # Кодирование
    LE = LabelEncoder()
    for col in bin_cols+cat_cols:
        if df[col].dtype == object:
            df[col] = df[col].fillna('Non_specified')
            df[col] = df[col].apply(lambda x: str(x))
            df[col] = LE.fit_transform(df[col])
    
    # Разделение переменных
    X = df[sorted(bin_cols+cat_cols+num_cols)].drop(['rur_price', 'eur_price', 'usd_price'], axis=1).values
    y = df[target].values
    
    # Создание списков для записи локальных результатов
    local_mape = []
    local_mae = []
    local_mse = []
    
    # Моделирование с 3-ой кросс-валидацией
    SKF = StratifiedKFold(n_splits=3, shuffle=True, random_state=RS)
    for train_index, test_index in SKF.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        model.fit(X_train, np.log(y_train), eval_set=(X_test, np.log(y_test)), verbose_eval=0, use_best_model=True) # <= Встроенная настройка
        preds = np.exp(model.predict(X_test))
        local_mape.append(MAPE(y_test, preds))
        local_mae.append(mean_absolute_error(y_test, preds))
        local_mse.append(mean_squared_error(y_test, preds)**(1/2))
    
    # Усреднение метрик
    result = []
    result.append(np.mean(local_mape))
    result.append(np.mean(local_mae))
    result.append(np.mean(local_mse))
    
    return result

# %%
# Расчет и запись метрик
results['CB_selftuning'] = metics(data[data.train==1], 'eur_price', model=CatBoostRegressor(iterations = 10000, random_seed = RS, 
                                                                                            eval_metric='MAPE', custom_metric=['R2', 'MAE'], 
                                                                                            silent=True))

# Визуализация
plot_results(results, 'MAPE')
results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#       target_set  post_cat  post_num  post_stat  post_txt  post_cleaning  \
# MAPE      0.1738    0.1743    0.1418     0.1383    0.1381         0.1375
# MAE    1664.7240 1675.0652 1636.6076  1557.9206 1561.6907      1554.0244
# RMSE   4951.5050 4941.1828 5260.0485  5050.2973 5109.3961      5168.8458
#
#       CB_selftuning
# MAPE         0.1325
# MAE       1433.7202
# RMSE      4796.2552

# %% [markdown]
# Результат модели стал лучше после встроенной настройки параметров в CatBoost

# %% [markdown]
# ### Обучение модели

# %%
train = data[data.train==1]

# Кодирование
LE = LabelEncoder()
for col in bin_cols+cat_cols:
    if train[col].dtype == object:
        train[col] = train[col].fillna('Non_specified')
        LE.fit(train[col])
        train[col] = LE.transform(train[col])

# Разделение выборки
X = train[sorted(bin_cols+cat_cols+num_cols)].drop(['rur_price', 'eur_price', 'usd_price'], axis=1).values
y = train['eur_price'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %%
# Создание модели
model = CatBoostRegressor(iterations = 10000,
                          random_seed = RS,
                          eval_metric='MAPE',
                          custom_metric=['R2', 'MAE'],
                          silent=True,
                         )
model.fit(X_train, np.log(y_train),
         eval_set=(X_test, np.log(y_test)),
         verbose_eval=0,
         use_best_model=True,
         plot=True
         )
# Out:
#             <style>
#                 .highcharts-tooltip {
#     display: none !important;
# }
# .highcharts-halo {
#     display: none !important;
# }
#
# .catboost {
#     position: relative;
# }
#
# .catboost-panel {
#     position: absolute;
#     height: 100%;
#     width: 280px;
# }
#
# .catboost-panel__controls {
#     margin-left: 0;
# }
#
# .catboost-panel__controls_label {
#     padding: 5px 0 0 8px;
#     cursor: pointer;
#     width: 80px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls_label_time {
#     width: inherit;
# }
#
# .catboost-panel__controls2 {
#     margin-top: 10px;
# }
#
# .catboost-panel__controls2_label {
#     padding: 5px 11px 0 8px;
#     cursor: pointer;
#     width: 90px;
#     box-sizing: content-box;
# }
# .catboost-panel__controls2_label-long {
#     width: 170px;
# }
#
# .catboost-panel__series {
#     height: 340px;
#     overflow-y: auto;
# }
#
# .catboost-graph {
#     margin-left: 290px;
# }
#
# .catboost-graph__tabs {
#     padding: 0 0 0 20px;
# }
#
# .catboost-graph__tab {
#     display: inline-block;
#     padding: 5px 10px 0 0;
# }
#
# .catboost-graph__tab {
#     color: #999;
#     cursor: pointer;
#     transition: color 0.1s linear;
# }
#
# .catboost-graph__tab:hover {
#     color: #333;
# }
#
# .catboost-graph__tab_active {
#     color: #000;
#     cursor: auto;
# }
#
# .catboost-graph__charts {
#     padding-top: 20px;
# }
#
# .catboost-graph__chart {
#     display: none;
# }
#
# .catboost-graph__chart_active {
#     display: block;
# }
#
# .catboost-panel__serie {
#     padding-bottom: 5px;
#     border-bottom: 1px solid rgba(0, 0, 0, 0.3);
#     position: relative;
# }
#
# .catboost-panel__serie_bottom,
# .catboost-panel__serie_middle,
# .catboost-panel__serie_top {
#     white-space: nowrap;
#     position: relative;
# }
#
# #catboost-control-test {
#     margin-left: 11px;
# }
#
# .catboost-panel__serie_label {
#     padding: 0 0 0 8px;
#     width: 200px;
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     cursor: pointer;
#     margin-bottom: 0;
#     overflow: hidden;
#     position: relative;
#     top: 5px;
# }
#
# .catboost-panel__serie_hint {
#     position: absolute;
#     font-size: 9px;
#     left: 0;
# }
#
# .catboost-panel__serie__learn_hint {
#     top: 56px;
# }
#
# .catboost-panel__serie__test_hint {
#     top: 82px;
# }
#
# .catboost-panel__serie_bottom {
#     padding-bottom: 6px;
# }
#
# .catboost-panel__serie_time {
#     position: absolute;
#     top: 5px;
#     right: 2px;
#     height: 20px;
#     padding: 0 0 0 20px;
#     margin-bottom: 3px;
#     overflow: hidden;
#
#     text-overflow: ellipsis;
#     box-sizing: border-box;
#     text-align: left;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_test_pic {
#     width: 13px;
#     height: 1px;
#     border-top-width: 1px;
#     position: relative;
#     top: -3px;
#     margin-right: 5px;
# }
#
# .catboost-panel__serie_learn_pic {
#     border-top-style: dashed;
# }
#
# .catboost-panel__serie_test_pic {
#     border-top-style: solid;
# }
#
# .catboost-panel__serie-value {
#     display: inline-block;
#     min-width: 30px;
#     margin-right: 2px;
# }
#
# .catboost-panel__controls_label .catboost-panel__serie_learn_pic {
#     padding-left: 4px;
# }
#
# .catboost-panel__serie_names {
#     white-space: nowrap;
# }
#
# .catboost-panel__serie_scroll {
#     width: 240px;
#     overflow-x: auto;
#     margin-left: 20px;
# }
#
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_learn_value,
# .catboost-panel__serie_best_test_value {
#     width: 85px;
#     position: relative;
#     padding: 0 8px 0 0;
#     box-sizing: content-box;
#     overflow: hidden;
#     text-overflow: ellipsis;
#     top: 5px;
# }
#
# .catboost-panel__serie_iteration,
# .catboost-panel__serie_best_iteration {
#     display: inline-block;
#     position: absolute;
#     box-sizing: content-box;
#     overflow: hidden;
#     right: 2px;
# }
#
# .catboost-panel__serie_iteration {
#     top: 55px;
# }
#
# .catboost-panel__serie_best_iteration {
#     top: 80px;
# }
#
# .catboost-panel__control_slider {
#     width: 100px !important;
#     margin-left: 0;
#     position: relative;
#     display: inline-block !important;
#     top: 3px;
# }
#
# .catboost-panel__control_slidervalue {
#     width: 50px;
#     padding: 2px 3px;
#     margin-left: 4px;
# }
#
# .catboost-panel__serie_time_spend,
# .catboost-panel__serie_time_left {
#     display: inline-block;
# }
#
# .catboost-panel__serie_time_left {
#     margin-left: 10px;
# }
#
# .catboost-panel__serie_learn_pic,
# .catboost-panel__serie_learn_name,
# .catboost-panel__serie_learn_value,
# .catboost-panel__serie_best_learn_value {
#     display: inline-block;
# }
# .catboost-panel__serie_test_pic,
# .catboost-panel__serie_test_name,
# .catboost-panel__serie_test_value,
# .catboost-panel__serie_best_test_value {
#     display: inline-block;
# }
#
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_pic,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_name,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_learn_value {
#     display: none;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_pic,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_name,
# .catboost-panel__series_test_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_test_value {
#     display: none;
# }
#
# /*
# .catboost-panel__series_learn_disabled .catboost-panel__serie_test_value,
# .catboost-panel__series_learn_disabled .catboost-panel__serie_best_test_value {
#     width: 216px;
# }
# .catboost-panel__series_test_disabled .catboost-panel__serie_learn_value,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_learn_value {
#     width: 216px;
# }
# */
# .catboost-panel__series_test_disabled .catboost-panel__serie__test_hint,
# .catboost-panel__series_test_disabled .catboost-panel__serie_best_iteration {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled.catboost-panel__series_learn_disabled .catboost-panel__serie_middle {
#     display: none;
# }
#
# .catboost-panel__series_test_disabled .catboost-panel__serie_bottom {
#     display: none;
# }
#
#             </style>
#             <script>
#                 window.__define = window.define;window.__require = window.require;window.define = undefined;window.require = undefined;/**
# * plotly.js (basic - minified) v1.27.1
# * Copyright 2012-2017, Plotly, Inc.
# * All rights reserved.
# * Licensed under the MIT license
# */
# !function(t){if("object"==typeof exports&&"undefined"!=typeof module)module.exports=t();else if("function"==typeof define&&define.amd)define([],t);else{var e;e="undefined"!=typeof window?window:"undefined"!=typeof global?global:"undefined"!=typeof self?self:this,e.Plotly=t()}}(function(){var t;return function t(e,r,n){function a(i,l){if(!r[i]){if(!e[i]){var s="function"==typeof require&&require;if(!l&&s)return s(i,!0);if(o)return o(i,!0);var c=new Error("Cannot find module '"+i+"'");throw c.code="MODULE_NOT_FOUND",c}var u=r[i]={exports:{}};e[i][0].call(u.exports,function(t){var r=e[i][1][t];return a(r||t)},u,u.exports,t,e,r,n)}return r[i].exports}for(var o="function"==typeof require&&require,i=0;i<n.length;i++)a(n[i]);return a}({1:[function(t,e,r){"use strict";var n=t("../src/lib"),a={"X,X div":"font-family:'Open Sans', verdana, arial, sans-serif;margin:0;padding:0;","X input,X button":"font-family:'Open Sans', verdana, arial, sans-serif;","X input:focus,X button:focus":"outline:none;","X a":"text-decoration:none;","X a:hover":"text-decoration:none;","X .crisp":"shape-rendering:crispEdges;","X .user-select-none":"-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;-o-user-select:none;user-select:none;","X svg":"overflow:hidden;","X svg a":"fill:#447adb;","X svg a:hover":"fill:#3c6dc5;","X .main-svg":"position:absolute;top:0;left:0;pointer-events:none;","X .main-svg .draglayer":"pointer-events:all;","X .cursor-default":"cursor:default;","X .cursor-pointer":"cursor:pointer;","X .cursor-crosshair":"cursor:crosshair;","X .cursor-move":"cursor:move;","X .cursor-col-resize":"cursor:col-resize;","X .cursor-row-resize":"cursor:row-resize;","X .cursor-ns-resize":"cursor:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))

# %%
# Предсказание теста
preds = np.exp(model.predict(X_test))
MAPE(y_test, preds)
# Out:
# 0.13317714904634412

# %% [markdown]
# ## Дополнительные модели
#
# Для улучшения результата, блэндинга и стэкинга будут использованы следующие модели:
# - Две базовые модели для противоположных эстремальных подходов:
# > - Глубокое дерево для максимального заучивания данных
# > - Линейная регрессия для отображения общего тренда
#
# - Альтернативные ансамбли:
# > - Стандартный бэггинг RandomForest
# > - Базовый градиентный бустинг от sklearn

# %% [markdown]
# ### Обработка данных

# %%
# Копия датафрейма
alt_data = data[bin_cols+cat_cols+num_cols+['train','sell_id']].drop(['rur_price', 'usd_price'], axis=1)
display(alt_data.sample(3))

na_values(alt_data)

print('Бинарные данные: \t', bin_cols)
print()
print('Категориальные данные: \t', cat_cols)
print()
print('Числовые данные: \t', num_cols)
# Out:
#           vendor   Руль       bodyType       brand fuelType model_name  \
# 124919  EUROPEAN  Левый     седан long         BMW   бензин        7ER
# 149471  EUROPEAN  Левый  хэтчбек 5 дв.  VOLKSWAGEN   бензин   GOLF_GTI
# 107161  EUROPEAN  Левый          седан        AUDI   дизель         A4
#
#        vehicleTransmission    Владельцы       ПТС    Привод comp_id    gen_id  \
# 124919      автоматическая  2 владельца  Оригинал    полный       0      None
# 149471        механическая  3 или более  Оригинал  передний       0      None
# 107161        механическая  3 или более  Дубликат  передний       0  21193364
#
#         eqp_amount  ord_brand  body  desc_cluster  eur_price     mileage  \
# 124919           0          9  седа             2 16158.0000 178000.0000
# 149471           0          4  хэтч             2  4457.0000 230480.0000
# 107161          28          8  седа             1     0.0000 320000.0000
#
#         modelDate  numberOfDoors  productionDate  eng_volume  eng_pwr  \
# 124919  2012.0000         4.0000       2012.0000      3.0000 320.0000
# 149471  1998.0000         5.0000       2001.0000      1.8000 150.0000
# 107161  2000.0000         4.0000       2001.0000      1.9000 130.0000
#
#         rel_model  eqp_rating  train         sell_id
# 124919     0.8947         nan      1            None
# 149471     0.4865         nan      1            None
# 107161     0.3333     -1.2138      0 1101311025.0000
# ВЛАДЕЛЬЦЫ
# %% пропущенных данных в столбце: 	7.0
# (%% от общего кол-ва данных: 	0.0)
#
# ПТС
# %% пропущенных данных в столбце: 	0.0
# (%% от общего кол-ва данных: 	0.0)
#
# GEN_ID
# %% пропущенных данных в столбце: 	30.0
# (%% от общего кол-ва данных: 	1.0)
#
# EQP_RATING
# %% пропущенных данных в столбце: 	54.0
# (%% от общего кол-ва данных: 	2.0)
#
# SELL_ID
# %% пропущенных данных в столбце: 	30.0
# (%% от общего кол-ва данных: 	1.0)
#
# Бинарные данные: 	 ['vendor', 'Руль']
#
# Категориальные данные: 	 ['bodyType', 'brand', 'fuelType', 'model_name', 'vehicleTransmission', 'Владельцы', 'ПТС', 'Привод', 'comp_id', 'gen_id', 'eqp_amount', 'ord_brand', 'body', 'desc_cluster']
#
# Числовые данные: 	 ['rur_price', 'eur_price', 'usd_price', 'mileage', 'modelDate', 'numberOfDoors', 'productionDate', 'eng_volume', 'eng_pwr', 'rel_model', 'eqp_rating']

# %% [markdown]
# Необходимо понять, как кодировать категориальные переменные:

# %%
short_cols = []
long_cols = []
for col in cat_cols:
    if len(alt_data[col].unique()) < 15:
        short_cols.append(col)
    else:
        long_cols.append(col)
print('Переменные для dummy-кодирования: \t', short_cols)
print()
print('Переменные для статистик: \t', long_cols)
# Out:
# Переменные для dummy-кодирования: 	 ['brand', 'fuelType', 'vehicleTransmission', 'Владельцы', 'ПТС', 'Привод', 'ord_brand', 'desc_cluster']
#
# Переменные для статистик: 	 ['bodyType', 'model_name', 'comp_id', 'gen_id', 'eqp_amount', 'body']

# %% [markdown]
# - В данном случае, не имеет смысла dummy-кодировать ord_brand, т.к. переменная продублирует brand.
# - eqp_amount скорее числовой признак.
# - По model_name уже есть числовой rel_model

# %%
# Правки
alt_data.drop('ord_brand', axis=1, inplace=True)
short_cols.remove('ord_brand')

long_cols.remove('eqp_amount')

alt_data.drop('model_name', axis=1, inplace=True)
long_cols.remove('model_name')

# %%
# Создание dummy-переменных. Для параметров с пропусками помечаем пропуски.
for col in short_cols:
    if len(alt_data[col].isna().unique())>1:
        alt_data = pd.get_dummies(alt_data, dummy_na=True, columns=[col])
    else:
        alt_data = pd.get_dummies(alt_data, dummy_na=False, columns=[col])

alt_data.sample(3)
# Out:
#           vendor    Руль         bodyType comp_id   gen_id  eqp_amount  body  \
# 97569   JAPANESE   Левый            седан       0  6389822          44  седа
# 105766  JAPANESE   Левый  универсал 5 дв.       0  2334576           0  унив
# 13524   JAPANESE  Правый            седан       0  4995341           0  седа
#
#         eur_price     mileage  modelDate  numberOfDoors  productionDate  \
# 97569      0.0000 255256.0000  2001.0000         4.0000       2003.0000
# 105766     0.0000 273000.0000  2000.0000         5.0000       2003.0000
# 13524   2496.0000 250000.0000  1995.0000         4.0000       2000.0000
#
#         eng_volume  eng_pwr  rel_model  eqp_rating  ...  Владельцы_1 владелец  \
# 97569       2.4000 152.0000     0.8661     -1.5292  ...                     0
# 105766      1.6000  98.0000     0.5745         nan  ...                     0
# 13524       2.5000 200.0000     0.2766         nan  ...                     0
#
#        Владельцы_2 владельца  Владельцы_3 или более  Владельцы_nan  \
# 97569                      0                      1              0
# 105766                     0                      1              0
# 13524                      0                      1              0
#
#         ПТС_Дубликат  ПТС_Оригинал  ПТС_nan  Привод_задний  Привод_передний  \
# 97569              0             1        0              0                1
# 105766             0             1        0              0                1
# 13524              1             0        0              0                1
#
#         Привод_полный  desc_cluster_0  desc_cluster_1  desc_cluster_2  \
# 97569               0               0               1               0
# 105766              0               0               0               0
# 13524               0               0               1               0
#
#         desc_cluster_3  desc_cluster_4  desc_cluster_5
# 97569                0               0               0
# 105766               0               0               1
# 13524                0               0               0
#
# [3 rows x 55 columns]

# %% [markdown]
# Заполним gen_id и eqp_rating. В случае с gen_id, это позволит отделить пропуски от остальных данных. Для eqp_rating, 0 - среднеарифметическое.

# %%
# Заполнение пропусков
alt_data.fillna(0, inplace=True)
alt_data.sample(3)
# Out:
#           vendor    Руль           bodyType   comp_id    gen_id  eqp_amount  \
# 1851    JAPANESE  Правый         компактвэн         0  21110897           0
# 117216  EUROPEAN   Левый  внедорожник 5 дв.  21630343         0           0
# 82168   JAPANESE   Левый              седан         0   2306778          23
#
#         body  eur_price     mileage  modelDate  numberOfDoors  productionDate  \
# 1851    комп  3152.0000  78000.0000  2002.0000         5.0000       2003.0000
# 117216  внед 40507.0000      0.0000  2017.0000         5.0000       2020.0000
# 82168   седа     0.0000 193611.0000  2005.0000         4.0000       2008.0000
#
#         eng_volume  eng_pwr  rel_model  eqp_rating  ...  Владельцы_1 владелец  \
# 1851        1.5000 110.0000     0.3333      0.0000  ...                     0
# 117216      2.0000 249.0000     0.6154      0.0000  ...                     0
# 82168       1.8000 140.0000     0.6852     -0.9424  ...                     0
#
#         Владельцы_2 владельца  Владельцы_3 или более  Владельцы_nan  \
# 1851                        1                      0              0
# 117216                      0                      0              1
# 82168                       1                      0              0
#
#         ПТС_Дубликат  ПТС_Оригинал  ПТС_nan  Привод_задний  Привод_передний  \
# 1851               0             1        0              0                1
# 117216             0             1        0              0                0
# 82168              0             1        0              0                1
#
#         Привод_полный  desc_cluster_0  desc_cluster_1  desc_cluster_2  \
# 1851                0               0               0               0
# 117216              1               0               0               1
# 82168               0               0               1               0
#
#         desc_cluster_3  desc_cluster_4  desc_cluster_5
# 1851                 0               0               1
# 117216               0               0               0
# 82168                0               0               0
#
# [3 rows x 55 columns]

# %% [markdown]
# Для категориальных переменных с большим кол-вом переменных, заменим их на стандартизированное среднее значение целовой для каждого уникального значения.
#
# Для значений, которые есть в тесте, но отсутствуют в трейне, берется самое частое значение полученной статистики.

# %%
for col in long_cols:
    means = (alt_data[alt_data.train==1].groupby(col).eur_price.mean() / alt_data.eur_price.std()).to_dict()
    alt_data['{}_stat'.format(col)] = alt_data[col].map(means)
    alt_data['{}_stat'.format(col)] = alt_data['{}_stat'.format(col)].fillna(alt_data['{}_stat'.format(col)].value_counts().index[0])
    alt_data.drop(col, axis=1, inplace=True)
alt_data.sample(3)
# Out:
#           vendor    Руль  eqp_amount   eur_price     mileage  modelDate  \
# 63735   JAPANESE  Правый           0   3620.0000 250000.0000  2003.0000
# 138186  EUROPEAN   Левый           0 235252.0000      0.0000  2018.0000
# 31782   EUROPEAN   Левый          42  11039.0000 345000.0000  2009.0000
#
#         numberOfDoors  productionDate  eng_volume  eng_pwr  rel_model  \
# 63735          5.0000       2003.0000      1.5000 109.0000     0.2362
# 138186         5.0000       2020.0000      4.0000 585.0000     0.8955
# 31782          5.0000       2010.0000      2.0000 177.0000     0.2632
#
#         eqp_rating  train         sell_id  brand_AUDI  brand_BMW  ...  \
# 63735       0.0000      1 1103305649.0000           0          0  ...
# 138186      0.0000      1          0.0000           0          0  ...
# 31782      -0.8216      1 1103007243.0000           0          1  ...
#
#         ПТС_Дубликат  ПТС_Оригинал  ПТС_nan  Привод_задний  Привод_передний  \
# 63735              0             1        0              0                1
# 138186             0             1        0              0                0
# 31782              0             1        0              0                0
#
#         Привод_полный  desc_cluster_0  desc_cluster_1  desc_cluster_2  \
# 63735               0               0               1               0
# 138186              1               0               0               1
# 31782               1               0               1               0
#
#         desc_cluster_3  desc_cluster_4  desc_cluster_5  bodyType_stat  \
# 63735                0               0               0         0.2655
# 138186               0               0               0         1.2145
# 31782                0               0               0         1.2145
#
#         comp_id_stat  gen_id_stat  body_stat
# 63735         0.5726       0.2488     0.2678
# 138186       10.7745       1.0032     1.2049
# 31782         0.5726       0.5433     1.2049
#
# [3 rows x 55 columns]

# %% [markdown]
# Перекодировка бинарных признаков:

# %%
LE = LabelEncoder()
for col in bin_cols:
    alt_data[col] = LE.fit_transform(alt_data[col])
alt_data.sample(3)
# Out:
#        vendor  Руль  eqp_amount  eur_price     mileage  modelDate  \
# 25133       1     0           1  4692.0000 233000.0000  2005.0000
# 26438       1     1           0  2263.0000 232000.0000  2000.0000
# 1337        1     1          25  7077.0000 230000.0000  2003.0000
#
#        numberOfDoors  productionDate  eng_volume  eng_pwr  rel_model  \
# 25133         5.0000       2007.0000      1.8000 140.0000     0.6852
# 26438         4.0000       2002.0000      1.5000 105.0000     0.2222
# 1337          5.0000       2004.0000      2.4000 200.0000     0.9630
#
#        eqp_rating  train         sell_id  brand_AUDI  brand_BMW  ...  \
# 25133     -0.4187      1 1102506167.0000           0          0  ...
# 26438      0.0000      1 1103158983.0000           0          0  ...
# 1337      -0.4859      1 1091867626.0000           0          0  ...
#
#        ПТС_Дубликат  ПТС_Оригинал  ПТС_nan  Привод_задний  Привод_передний  \
# 25133             1             0        0              0                1
# 26438             0             1        0              0                1
# 1337              0             1        0              0                1
#
#        Привод_полный  desc_cluster_0  desc_cluster_1  desc_cluster_2  \
# 25133              0               0               1               0
# 26438              0               0               1               0
# 1337               0               0               1               0
#
#        desc_cluster_3  desc_cluster_4  desc_cluster_5  bodyType_stat  \
# 25133               0               0               0         0.3042
# 26438               0               0               0         0.5536
# 1337                0               0               0         0.2655
#
#        comp_id_stat  gen_id_stat  body_stat
# 25133        0.5726       0.2535     0.2936
# 26438        0.5726       0.1466     0.6006
# 1337         0.5726       0.3156     0.2678
#
# [3 rows x 55 columns]

# %% [markdown]
# ### LazyPredict

# %%
# Посмотрим, какие еще модели могут представлять интерес
# Обучим LazyRegressor на небольших выборках из датасета, чтобы быстрее шел расчет

scaler = StandardScaler()

small_data = alt_data[alt_data.train==1].sample(20000).drop(['train','sell_id'], axis=1).copy()

X = small_data.drop('eur_price', axis=1).values
X = scaler.fit_transform(X) 
y = small_data['eur_price'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=RS)

regr=LazyRegressor(verbose=0,predictions=True)

models_r,predictions_r=regr.fit(X_train, X_test, np.log(y_train), np.log(y_test))

models_r

# %%
small_data = alt_data[alt_data.train==1].sample(20000).drop(['train','sell_id'], axis=1).copy()

X = small_data.drop('eur_price', axis=1).values
X = scaler.fit_transform(X) 
y = small_data['eur_price'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=RS)

regr=LazyRegressor(verbose=0,predictions=True)

models_r,predictions_r=regr.fit(X_train, X_test, np.log(y_train), np.log(y_test))

models_r

# %% [markdown]
# По результатам применения LazyRegressor, можно сделать вывод, что стоит применить Extra Trees и Light GBM

# %% [markdown]
# ### Оценка

# %%
# Функция возвращает метрики для данных и модели (MAPE с кросс-валидацией и без нее)
def alt_metics(data, target, model=CatBoostRegressor(random_seed = RS, silent=True)):
    df = data[data.train==1].drop(['train','sell_id'], axis=1).copy()
    
    # Разделение переменных
    X = df.drop(target, axis=1).values
    y = df[target].values
    
    # Создание списков для записи локальных результатов
    local_mape = []
    
    # Моделирование с 3-ой кросс-валидацией
    SKF = StratifiedKFold(n_splits=3, shuffle=True, random_state=RS)
    for train_index, test_index in SKF.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        model.fit(X_train, np.log(y_train))
        preds = np.exp(model.predict(X_test))
        local_mape.append(MAPE(y_test, preds))
    
    # Усреднение метрики
    result = []
    result.append(np.mean(local_mape))
    
    # Добавление метрики без кросс-валидации
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)
    model.fit(X_train, np.log(y_train))
    preds = np.exp(model.predict(X_test))
    result.append(MAPE(y_test, preds))
    
    return result

# %% [markdown]
# ### DecisionTree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DT = DecisionTreeRegressor(random_state=RS)

alt_results = pd.DataFrame({'DT': alt_metics(alt_data, 'eur_price', model=DT)}, 
                           index = ['CV','TST0.3'])
alt_results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            DT
# CV     0.2005
# TST0.3 0.2003

# %%
# Подбор параметров

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)

DF = DecisionTreeRegressor(random_state=RS)

splitter = ['best', 'random']
max_features = ['auto', 'sqrt', 'log2', None]
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]

random_grid = {'splitter': splitter,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               }

DF_random = RandomizedSearchCV(estimator = DF, param_distributions = random_grid, 
                               n_iter = 100, cv = 3, verbose=2, random_state=RS, n_jobs=-1)
DF_random.fit(X_train, np.log(y_train))

DF_random.best_params_

# %% [markdown]
# Лучшие параметры: {'splitter': 'random',
#                      'min_samples_split': 10,
#                      'min_samples_leaf': 4,
#                      'max_features': 'auto',
#                      'max_depth': 90}

# %%
# Обучим модель с подобранными параметрами
DT = DecisionTreeRegressor(splitter='random', 
                           min_samples_split=10, 
                           min_samples_leaf=4, 
                           max_features='auto', 
                           max_depth=90, 
                           random_state=RS)
alt_results['DT_new'] = alt_metics(alt_data, 'eur_price', model=DT)

alt_results

# %% [markdown]
# Метрика улучшилась, но осталась хуже CatBoost

# %% [markdown]
# ### Linear regression

# %%
LR = LinearRegression(n_jobs=-1)
alt_results['LR'] = alt_metics(alt_data, 'eur_price', model=LR)

alt_results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            DT      LR
# CV     0.2005 66.7258
# TST0.3 0.2003  0.2294

# %%
# Функция возвращает метрики для нормализованных данных и модели (MAPE с кросс-валидацией и без нее)
def norm_alt_metics(data, target, scaler, model=CatBoostRegressor(random_seed = RS, silent=True)):
    df = data[data.train==1].drop(['train','sell_id'], axis=1).copy()
    
    # Разделение переменных
    X = df.drop(target, axis=1).values
    X = scaler.fit_transform(X) 
    y = df[target].values
    
    # Создание списков для записи локальных результатов
    local_mape = []
    
    # Моделирование с 3-ой кросс-валидацией
    SKF = StratifiedKFold(n_splits=3, shuffle=True, random_state=RS)
    for train_index, test_index in SKF.split(X, y):
        X_train, X_test = X[train_index], X[test_index]
        y_train, y_test = y[train_index], y[test_index]
        
        model.fit(X_train, np.log(y_train))
        preds = np.exp(model.predict(X_test))
        local_mape.append(MAPE(y_test, preds))
    
    # Усреднение метрики
    result = []
    result.append(np.mean(local_mape))
    
    # Добавление метрики без кросс-валидации
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)
    model.fit(X_train, np.log(y_train))
    preds = np.exp(model.predict(X_test))
    result.append(MAPE(y_test, preds))
    
    return result

# %%
# Построим линейную регрессию, построенную на признаках, нормализованных с помощью StandardScaler
LR = LinearRegression(n_jobs=-1)

alt_results['LR(ss)'] = norm_alt_metics(alt_data, 'eur_price', scaler=RobustScaler(), model=LR)

alt_results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            DT      LR  LR(ss)
# CV     0.2005 66.7258 67.2056
# TST0.3 0.2003  0.2294  0.2294

# %%
# Построим линейную регрессию, построенную на признаках, нормализованных с помощью RobustScaler
from sklearn.preprocessing import RobustScaler

LR = LinearRegression(n_jobs=-1)

alt_results['LR(rs)'] = norm_alt_metics(alt_data, 'eur_price', scaler=RobustScaler(), model=LR)

alt_results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            DT      LR  LR(ss)  LR(rs)
# CV     0.2005 66.7258 67.2056 67.2056
# TST0.3 0.2003  0.2294  0.2294  0.2294

# %% [markdown]
# Линейная регрессия работает плохо, что было ожидаемо. Стандартизация не даёт улучшений.

# %%
alt_results.drop(['LR(ss)','LR(rs)'], axis=1, inplace=True)

# %% [markdown]
# ### Random Forest

# %%
# Параметры по умолчанию
RF = RandomForestRegressor(random_state=RS)

alt_results['RF'] =  alt_metics(alt_data, 'eur_price', model=RF)

alt_results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            DT      LR     RF
# CV     0.2005 66.7258 0.1374
# TST0.3 0.2003  0.2294 0.1383

# %%
# Подбор гиперпараметров
# Код спрятали в текст, потому что долго считает
'''X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)

RF = RandomForestRegressor(random_state=RS)

n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]
max_features = ['auto', 'sqrt']
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
min_samples_split = [2, 5, 10]
min_samples_leaf = [1, 2, 4]
bootstrap = [True, False]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

RF_random = RandomizedSearchCV(estimator = RF, param_distributions = random_grid, 
                               n_iter = 100, cv = 3, verbose=2, random_state=RS, n_jobs = -1)
RF_random.fit(X_train, y_train)
# Посмотрим, какие гиперпараметры нам предлагают как оптимальные:
RF_random.best_params_'''

# %% [markdown]
# Получили следующие значения:
#
# 'n_estimators': 1400,
#
# 'min_samples_split': 5,
#
# 'min_samples_leaf': 1,
#
# 'max_features': 'sqrt',
#
# 'max_depth': 80,
#
# 'bootstrap': False

# %%
# Обучим модель с новыми параметрами
RF = RandomForestRegressor(n_estimators=1400, 
                           min_samples_split=5, 
                           min_samples_leaf=1, 
                           max_features='sqrt', 
                           max_depth=80, 
                           bootstrap=False, 
                           random_state=RS)

alt_results['RF_new'] = alt_metics(alt_data, 'eur_price', model=RF)
alt_results

# %% [markdown]
# ### Extra Trees

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
# Параметры по умолчанию
ET = ExtraTreesRegressor(random_state=RS)

alt_results['ET'] =  alt_metics(alt_data, 'eur_price', model=ET)

alt_results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            DT      LR     RF     ET
# CV     0.2005 66.7258 0.1374 0.1420
# TST0.3 0.2003  0.2294 0.1383 0.1431

# %%
# Подбор параметров
'''X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)

ETR = ExtraTreesRegressor(random_state=RS)

param_grid = {'learning_rate':[0.0001, 0.001, 0.01, 0.1, 1], 
              'n_estimators':[100, 250, 500, 750, 1000],
              'max_depth': [10, 25, 40, 55, 70, 85, 100, None], 
              'min_samples_split': [2, 5, 10], 
              'min_samples_leaf': [1, 2, 4], 
              'max_features': ['auto', 'sqrt']}
gridsearch = GridSearchCV(GB, param_grid, n_jobs=-1, cv=3)
gridsearch.fit(X_train, y_train)
model = gridsearch.best_estimator_

# печатаем параметры
best_parameters = model.get_params()
for param_name in best_parameters:
    print(param_name, best_parameters[param_name], '\n')'''
# Не хватает мощности для вычислений

# %% [markdown]
# Подобрать оптимальные параметры не смогли, не хватает вычислительной мощности

# %% [markdown]
# ### Gradient Boosting

# %%
# Параметры по умолчанию
GB = GradientBoostingRegressor(random_state=RS)

alt_results['GB'] =  alt_metics(alt_data, 'eur_price', model=GB)

alt_results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            DT      LR     RF     ET     GB
# CV     0.2005 66.7258 0.1374 0.1420 0.1803
# TST0.3 0.2003  0.2294 0.1383 0.1431 0.1816

# %%
# Подбор параметров
'''X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)

GB = GradientBoostingRegressor(random_state=RS)

param_grid = {'learning_rate':[0.00001, 0.0001, 0.001, 0.01, 0.1, 1], 
              'n_estimators':[100, 250, 500, 750, 1000]}
gridsearch = GridSearchCV(GB, param_grid, n_jobs=-1, cv=3)
gridsearch.fit(X_train, y_train)
model = gridsearch.best_estimator_

# печатаем параметры
best_parameters = model.get_params()
for param_name in best_parameters:
    print(param_name, best_parameters[param_name], '\n')'''

# Не хватило производительности

# %% [markdown]
# ### Light  GBM

# %%
from lightgbm import LGBMRegressor

# %%
# Параметры по умолчанию
LGBM = LGBMRegressor(random_state=RS)

alt_results['LGBM'] =  alt_metics(alt_data, 'eur_price', model=LGBM)

alt_results
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=3.
#   % (min_groups, self.n_splits)), UserWarning)
#            DT      LR     RF     ET     GB   LGBM
# CV     0.2005 66.7258 0.1374 0.1420 0.1803 0.1484
# TST0.3 0.2003  0.2294 0.1383 0.1431 0.1816 0.1491

# %% [markdown]
# ## Stacking

# %%
from sklearn.ensemble import StackingRegressor

# %%
estimators = [('CB', model), ('DT', DT), ('LR', LR), ('RF', RF), ('ET', ET), ('GB', GB), ('LGBM', LGBM)]

STACK = StackingRegressor(estimators=estimators, verbose=2, 
                          final_estimator=RandomForestRegressor(n_estimators=25,
                                                                random_state=RS))

df = alt_data[alt_data.train==1].drop(['train','sell_id'], axis=1).copy()
    
X = df.drop('eur_price', axis=1).values
y = df['eur_price'].values
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)
STACK.fit(X_train, np.log(y_train))
preds = np.exp(STACK.predict(X_test))
MAPE(y_test, preds)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  8.9min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.6s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   58.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.9min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   49.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.1min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.3s finished
# 0.13698107854752772

# %%
estimators = [('CB', model), ('DT', DT), ('LR', LR), ('RF', RF), ('ET', ET), ('GB', GB), ('LGBM', LGBM)]

STACK = StackingRegressor(estimators=estimators, verbose=2, passthrough=True,
                          final_estimator=RandomForestRegressor(n_estimators=25, random_state=RS))

df = alt_data[alt_data.train==1].drop(['train','sell_id'], axis=1).copy()
    
X = df.drop('eur_price', axis=1).values
y = df['eur_price'].values
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)
STACK.fit(X_train, np.log(y_train))
preds = np.exp(STACK.predict(X_test))
MAPE(y_test, preds)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.8min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  9.4min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.7s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    0.5s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   60.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.8min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   50.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.2min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   17.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  1.5min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.2s finished
# 0.13539163061642798

# %%
estimators = [('CB', model), ('RF', RF), ('LGBM', LGBM)]

STACK = StackingRegressor(estimators=estimators, verbose=2,
                          final_estimator=RandomForestRegressor(n_estimators=25,
                                                                random_state=RS))

df = alt_data[alt_data.train==1].drop(['train','sell_id'], axis=1).copy()
    
X = df.drop('eur_price', axis=1).values
y = df['eur_price'].values
    
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=RS)
STACK.fit(X_train, np.log(y_train))
preds = np.exp(STACK.predict(X_test))
MAPE(y_test, preds)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  1.7min remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  8.6min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   58.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  4.8min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    4.0s finished
# 0.14318063578765516

# %% [markdown]
# # Post processing

# %% [markdown]
# ## Курс

# %%
# Разбиение рублевой переменной
y_rur_train, y_rur_test = train_test_split(train['rur_price'].values, test_size=0.3, shuffle=True, random_state=RS)

# Визуализация курса
sns.distplot(y_rur_test/y_test, kde=True)

# %% [markdown]
# Предпологая, что пересчет цены в рублях не происходит постоянно, возьмем курс на среднюю дату выгрузки.

# %%
pd.to_datetime(data[data.train==0].parsing_unixtime.mean() ,unit='s')
# Out:
# Timestamp('2020-10-21 13:25:33.619356394')

# %% [markdown]
# Курс евро по ЦБ РФ:
# - 91.5603

# %%
# Обработка
preds = preds*91.5603

# %%
MAPE(y_rur_test, preds)
# Out:
# 0.14687690762854172

# %% [markdown]
# Ожидаемо, ошибка выросла, т.к. курс взят на среднюю дату выгрузки тестовой выборки

# %% [markdown]
# ## Rounding

# %%
# Тестирование округлений от десятков до сотен тысяч рублей
for_processing = pd.DataFrame({'degree':[x for x in range(1,6)]})
for_processing['MAPE'] = for_processing.degree.apply(lambda x: MAPE(y_rur_test, (np.round(preds/(10**x)))*(10**x)))
for_processing[for_processing.MAPE==for_processing.MAPE.min()]
# Out:
#    degree   MAPE
# 2       3 0.1469

# %% [markdown]
# Наиболее точно округление до десятков тысяч рублей.

# %% [markdown]
# ## Итог:

# %%
# Функция пост-обработки результата
def post_proc(predictions):
    step_1 = np.exp(predictions)*91.5603
    return (np.round(step_1/(10**4)))*(10**4)

# %% [markdown]
# Лучшей моделью оказалась CatBoost, ее и запустим для submission

# %% [markdown]
# # Submission

# %%
valid = data[data.train==0]
valid_sell_id = valid.sell_id
valid['comp_id'] = valid.comp_id.apply(lambda x: str(x))

# Кодирование
LE = LabelEncoder()
for col in (bin_cols+cat_cols):
    if valid[col].dtype == object:
        valid[col] = valid[col].fillna('Non_specified')
        valid[col] = LE.fit_transform(valid[col])

# Разделение выборки
X_valid = valid[sorted(bin_cols+cat_cols+num_cols)].drop(['rur_price', 'eur_price', 'usd_price'], axis=1).values
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Предсказание
valid_preds = post_proc(model.predict(X_valid))

# %%
submission = pd.DataFrame({'sell_id': valid_sell_id, 
                           'price': valid_preds})
submission['sell_id'] = submission.sell_id.apply(lambda x: int(x))
submission.sample(5)
# Out:
#            sell_id         price
# 103521  1048870400   310000.0000
# 93044   1101137522 10860000.0000
# 96562   1093133096  1490000.0000
# 110125  1101356095   660000.0000
# 102012  1101212650   220000.0000

# %%
submission.to_csv('submission.csv', index=False)
